# %%
# Generic
import numpy as np  # linear algebra
import pandas as pd  # data processing, CSV file I/O (e.g. pd.read_csv)
import os, gc, re, warnings
import requests
from pprint import pprint

warnings.filterwarnings("ignore")

# Plot
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading Universal Sentence Encoder

import tensorflow as tf
import tensorflow_hub as hub

encoder = hub.load("./model")

# %%
# Custom Function to Estimate & then plot(heatmap) the text similarity


def plot_similarity(labels, features, rotation):
    corr = np.inner(features, features)
    sns.set(font_scale=1.2)
    plt.figure(figsize=(10, 10))
    g = sns.heatmap(
        corr,
        xticklabels=labels,
        yticklabels=labels,
        vmin=0,
        vmax=1,
        cmap="coolwarm",
        robust=True,
        cbar=False,
        square=True,
        annot=True,
    )
    g.set_xticklabels(labels, rotation=rotation)
    g.set_title("Semantic Similarity", fontsize=25)


def run_and_plot(messages_):
    message_embeddings_ = encoder(messages_)
    plot_similarity(messages_, message_embeddings_, 90)

# %%
messages = [
    # Shipping
    "What has happened to my delivery?",
    "What is wrong with my shipping?",
    # Weather
    "What is the weather like tomorrow?",
    "Will it snow tomorrow?",
    # Health
    "An apple a day, keeps the doctors away",
    "Eating apples is healthy",
    # Age
    "How old are you?",
    "what is your age?",
]

run_and_plot(messages)

# %%
def simularity(word1, word2):
    features = encoder([word1, word2])
    inner = np.inner(features, features)
    return inner[1][0]

# %%
simularity("tv, sound, image", "Sound and image")
# Out:
# 0.5630873

# %%
simularity("Headphones accessories", "Headphones")
# Out:
# 0.8231752

# %%
from google.cloud import translate

client = translate.TranslationServiceClient()
location = "global"
parent = f"projects/prisfinder/locations/{location}"  # project id 789995683879


def translate_to_eng(text: str):
    response = client.translate_text(
        request={
            "parent": parent,
            "contents": [text],
            "mime_type": "text/plain",
            "source_language_code": "nb-NO",
            "target_language_code": "en",
        }
    )

    return response.translations[0].translated_text


print(translate_to_eng("true-wireless-hodetelefoner"))
print(translate_to_eng("oerepropper"))
# Out:
# true wireless headphones
# earplugs

# %%
# Download finn categories


def download_finn_categories():
    url = (
        "https://www.finn.no/api/search-qf?searchkey=SEARCH_ID_BAP_COMMON&vertical=bap"
    )

    response = requests.get(url)
    data = response.json()
    filters = data["filters"]

    categories = next(x for x in filters if x["name"] == "category")

    def gen(filter_items, parent=None):
        for filter_item in filter_items:
            value = filter_item["value"]
            value_end = value.split(".")[-1]
            name = filter_item["display_name"]
            yield {
                "name": name,
                "name_eng": translate_to_eng(name),
                "id": value_end,
                "depth": value.split(".")[0],
                "parent": parent,
            }

            yield from gen(filter_item["filter_items"], parent=value_end)

    return [*gen(categories["filter_items"])]


found_categories = download_finn_categories()

pprint(found_categories)
# Out:
# [{'depth': '0',
#   'id': '76',
#   'name': 'Antikviteter og kunst',
#   'name_eng': 'Antiquities and art',
#   'parent': None},
#  {'depth': '1',
#   'id': '5175',
#   'name': 'Andre antikviteter',
#   'name_eng': 'Other antiques',
#   'parent': '76'},
#  {'depth': '1',
#   'id': '5178',
#   'name': 'Antikke møbler',
#   'name_eng': 'Antique furniture',
#   'parent': '76'},
#  {'depth': '1',
#   'id': '5176',
#   'name': 'Keramikk, porselen og glass',
#   'name_eng': 'Ceramics, porcelain and glass',
#   'parent': '76'},
#  {'depth': '1',
#   'id': '5177',
#   'name': 'Kunst',
#   'name_eng': 'Art',
#   'parent': '76'},
#  {'depth': '2',
#   'id': '385',
#   'name': 'Akryl',
#   'name_eng': 'Acrylic',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '386',
#   'name': 'Akvarell',
#   'name_eng': 'Watercolor',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '395',
#   'name': 'Annen kunst',
#   'name_eng': 'Other art',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '387',
#   'name': 'Blandingsteknikker',
#   'name_eng': 'Mixing techniques',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '388',
#   'name': 'Fotografi',
#   'name_eng': 'Photograph',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '389',
#   'name': 'Litografi',
#   'name_eng': 'Lithography',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '390',
#   'name': 'Oljemaleri',
#   'name_eng': 'Oil painting',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '391',
#   'name': 'Skulptur',
#   'name_eng': 'Sculpture',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '392',
#   'name': 'Tegning',
#   'name_eng': 'Drawing',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '393',
#   'name': 'Tresnitt',
#   'name_eng': 'Woodcut',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '394',
#   'name': 'Trykk',
#   'name_eng': 'Press',
#   'parent': '5177'},
#  {'depth': '1',
#   'id': '5179',
#   'name': 'Sølvtøy og bestikk',
#   'name_eng': 'Silverware and cutlery',
#   'parent': '76'},
#  {'depth': '0',
#   'id': '77',
#   'name': 'Dyr og utstyr',
#   'name_eng': 'Animals and equipment',
#   'parent': None},
#  {'depth': '1',
#   'id': '3976',
#   'name': 'Akvarier',
#   'name_eng': 'Aquariums',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5183',
#   'name': 'Andre dyr',
#   'name_eng': 'Other animals',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5185',
#   'name': 'Annet dyreutstyr',
#   'name_eng': 'Other animal equipment',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '3977',
#   'name': 'Bur',
#   'name_eng': 'Cage',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5206',
#   'name': 'Fisker',
#   'name_eng': 'Fisherman',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5205',
#   'name': 'Fugler',
#   'name_eng': 'Birds',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5186',
#   'name': 'Fôrverter, dyrepass, avl og stallplasser',
#   'name_eng': 'Feeders, animal care, breeding and stables',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5207',
#   'name': 'Gnagere og kaniner',
#   'name_eng': 'Rodents and rabbits',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5195',
#   'name': 'Heste- og rideutstyr',
#   'name_eng': 'Horse and riding equipment',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5190',
#   'name': 'Hester',
#   'name_eng': 'Horses',
#   'parent': '77'},
#  {'depth': '2',
#   'id': '36',
#   'name': 'Kaldblodshester',
#   'name_eng': 'Cold-blooded horses',
#   'parent': '5190'},
#  {'depth': '2',
#   'id': '37',
#   'name': 'Ponnier',
#   'name_eng': 'Ponies',
#   'parent': '5190'},
#  {'depth': '2',
#   'id': '38',
#   'name': 'Varmblodshester',
#   'name_eng': 'Warmblood horses',
#   'parent': '5190'},
#  {'depth': '1',
#   'id': '5192',
#   'name': 'Hunder',
#   'name_eng': 'Dogs',
#   'parent': '77'},
#  {'depth': '2',
#   'id': '21',
#   'name': 'Apporterende hunder',
#   'name_eng': 'Fetching dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '22',
#   'name': 'Blandingshunder',
#   'name_eng': 'Mixed breed dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '23',
#   'name': 'Bruks-, hyrde- og gjeterhunder',
#   'name_eng': 'Working, herding and herding dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '24',
#   'name': 'Dachs-, drivende og sporhunder',
#   'name_eng': 'Dachshund, driving and tracking dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '25',
#   'name': 'Mynder',
#   'name_eng': 'Figures',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '26',
#   'name': 'Pinscher-, schnauzer-, molosser og sennenhunder',
#   'name_eng': 'Pinschers, schnauzers, molossers and mountain dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '27',
#   'name': 'Selskapshunder',
#   'name_eng': 'Companion dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '28',
#   'name': 'Spisshunder',
#   'name_eng': 'Spitz dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '29',
#   'name': 'Stående fuglehunder',
#   'name_eng': 'Standing bird dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '501',
#   'name': 'Terriere',
#   'name_eng': 'Terriers',
#   'parent': '5192'},
#  {'depth': '1',
#   'id': '5193',
#   'name': 'Hundeutstyr',
#   'name_eng': 'Dog equipment',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5208',
#   'name': 'Insekter og edderkopper',
#   'name_eng': 'Insects and spiders',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5191',
#   'name': 'Katter',
#   'name_eng': 'Cats',
#   'parent': '77'},
#  {'depth': '2',
#   'id': '31',
#   'name': 'Blandingskatter',
#   'name_eng': 'Mixed taxes',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '32',
#   'name': 'Korthåret',
#   'name_eng': 'The short hair',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '33',
#   'name': 'Orientalere',
#   'name_eng': 'Orientals',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '34',
#   'name': 'Persere',
#   'name_eng': 'Persians',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '35',
#   'name': 'Semi-langhåret',
#   'name_eng': 'Semi-long haired',
#   'parent': '5191'},
#  {'depth': '1',
#   'id': '5194',
#   'name': 'Katteutstyr',
#   'name_eng': 'Cat equipment',
#   'parent': '77'},
#  {'depth': '1',
#   'id': '5210',
#   'name': 'Reptiler',
#   'name_eng': 'Reptiles',
#   'parent': '77'},
#  {'depth': '0',
#   'id': '93',
#   'name': 'Elektronikk og hvitevarer',
#   'name_eng': 'Electronics and appliances',
#   'parent': None},
#  {'depth': '1',
#   'id': '3215',
#   'name': 'Data',
#   'name_eng': 'Data',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '43',
#   'name': 'Bærbar PC',
#   'name_eng': 'Laptop',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '46',
#   'name': 'Datatilbehør',
#   'name_eng': 'Computer accessories',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '47',
#   'name': 'Kalkulatorer',
#   'name_eng': 'Calculators',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '49',
#   'name': 'Programvare',
#   'name_eng': 'Software',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '45',
#   'name': 'Skjermer',
#   'name_eng': 'Screens',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '44',
#   'name': 'Stasjonær PC',
#   'name_eng': 'Stationary PC',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '48',
#   'name': 'Tablet og lesebrett',
#   'name_eng': 'Tablet and reading board',
#   'parent': '3215'},
#  {'depth': '1',
#   'id': '3904',
#   'name': 'Foto og video',
#   'name_eng': 'Photo and video',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '505',
#   'name': 'Annet fotoutstyr',
#   'name_eng': 'Other photo equipment',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '500',
#   'name': 'Fotovesker og -bager',
#   'name_eng': 'Photo bags and backpacks',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '303',
#   'name': 'Hybridkamera',
#   'name_eng': 'Hybrid camera',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '502',
#   'name': 'Kompaktkameraer',
#   'name_eng': 'Compact cameras',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '503',
#   'name': 'Objektiver',
#   'name_eng': 'Objectives',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '66',
#   'name': 'Systemkameraer',
#   'name_eng': 'System cameras',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '504',
#   'name': 'Videokameraer',
#   'name_eng': 'Video cameras',
#   'parent': '3904'},
#  {'depth': '1',
#   'id': '3216',
#   'name': 'Husholdningsapparater',
#   'name_eng': 'Household appliances',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '304',
#   'name': 'Andre apparater',
#   'name_eng': 'Other appliances',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '83',
#   'name': 'Blender',
#   'name_eng': 'Blender',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '87',
#   'name': 'Brødrister',
#   'name_eng': 'Toaster',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '506',
#   'name': 'Kaffemaskin',
#   'name_eng': 'Coffee machine',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '507',
#   'name': 'Kjøkkenmaskin og foodprosessor',
#   'name_eng': 'Kitchen machine and food processor',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '89',
#   'name': 'Miksere',
#   'name_eng': 'Mixers',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '84',
#   'name': 'Strykejern',
#   'name_eng': 'Iron',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '81',
#   'name': 'Støvsuger',
#   'name_eng': 'Vacuum cleaner',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '88',
#   'name': 'Vaffel- og toastjern',
#   'name_eng': 'Waffle and toast iron',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '85',
#   'name': 'Vannkoker',
#   'name_eng': 'Kettle',
#   'parent': '3216'},
#  {'depth': '1',
#   'id': '3907',
#   'name': 'Hvitevarer',
#   'name_eng': 'Appliances',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '305',
#   'name': 'Andre hvitevarer',
#   'name_eng': 'Other white goods',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '72',
#   'name': 'Frysere',
#   'name_eng': 'Freezers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '74',
#   'name': 'Innbyggingsovner',
#   'name_eng': 'Built-in ovens',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '292',
#   'name': 'Kjøleskap',
#   'name_eng': 'Refrigerator',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '73',
#   'name': 'Komfyrer',
#   'name_eng': 'Stoves',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '508',
#   'name': 'Mikrobølgeovner',
#   'name_eng': 'Microwave ovens',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '509',
#   'name': 'Oppvaskmaskiner',
#   'name_eng': 'Dishwashers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '75',
#   'name': 'Platetopper',
#   'name_eng': 'Plate tops',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '510',
#   'name': 'Tørketromler',
#   'name_eng': 'Tumble dryers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '79',
#   'name': 'Vaskemaskiner',
#   'name_eng': 'Washing machines',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '511',
#   'name': 'Ventilatorer',
#   'name_eng': 'Ventilators',
#   'parent': '3907'},
#  {'depth': '1',
#   'id': '3906',
#   'name': 'Lyd og bilde',
#   'name_eng': 'Sound and image',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '56',
#   'name': 'Bluray-spillere',
#   'name_eng': 'Bluray players',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '57',
#   'name': 'DVD-spillere',
#   'name_eng': 'DVD players',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '61',
#   'name': 'Digital-TV og mediabokser',
#   'name_eng': 'Digital TV and media boxes',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '52',
#   'name': 'Forsterkere og receivere',
#   'name_eng': 'Amplifiers and receivers',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '59',
#   'name': 'Hjemmekinoanlegg',
#   'name_eng': 'Home cinema system',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '51',
#   'name': 'Hodetelefoner',
#   'name_eng': 'Headphones',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '53',
#   'name': 'Høyttalere',
#   'name_eng': 'Speakers',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '326',
#   'name': 'Kabler og tilbehør',
#   'name_eng': 'Cables and accessories',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '50',
#   'name': 'MP3 og bærbar lyd',
#   'name_eng': 'MP3 and portable audio',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '54',
#   'name': 'PA-utstyr',
#   'name_eng': 'PA equipment',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '60',
#   'name': 'Projektor og lerret',
#   'name_eng': 'Projector and screen',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '302',
#   'name': 'Radio',
#   'name_eng': 'Radio',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '55',
#   'name': 'Stereo',
#   'name_eng': 'Stereo',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '62',
#   'name': 'TV',
#   'name_eng': 'Television',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '58',
#   'name': 'Videospillere',
#   'name_eng': 'Video players',
#   'parent': '3906'},
#  {'depth': '1',
#   'id': '3905',
#   'name': 'Spill og konsoll',
#   'name_eng': 'Games and console',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '64',
#   'name': 'Spill',
#   'name_eng': 'Game',
#   'parent': '3905'},
#  {'depth': '2',
#   'id': '63',
#   'name': 'Spillkonsoller',
#   'name_eng': 'Game consoles',
#   'parent': '3905'},
#  {'depth': '2',
#   'id': '65',
#   'name': 'Tilbehør',
#   'name_eng': 'Accessories',
#   'parent': '3905'},
#  {'depth': '1',
#   'id': '3217',
#   'name': 'Telefoner og tilbehør',
#   'name_eng': 'Phones and accessories',
#   'parent': '93'},
#  {'depth': '2',
#   'id': '40',
#   'name': 'Andre telefoner',
#   'name_eng': 'Other phones',
#   'parent': '3217'},
#  {'depth': '2',
#   'id': '39',
#   'name': 'Mobiltelefoner',
#   'name_eng': 'Mobile phones',
#   'parent': '3217'},
#  {'depth': '2',
#   'id': '41',
#   'name': 'Telefontilbehør',
#   'name_eng': 'Phone accessories',
#   'parent': '3217'},
#  {'depth': '1',
#   'id': '3213',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '93'},
#  {'depth': '0',
#   'id': '68',
#   'name': 'Foreldre og barn',
#   'name_eng': 'Parents and children',
#   'parent': None},
#  {'depth': '1',
#   'id': '3913',
#   'name': 'Barneklær',
#   'name_eng': "Children's clothing",
#   'parent': '68'},
#  {'depth': '2',
#   'id': '341',
#   'name': 'Baby',
#   'name_eng': 'Baby',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '342',
#   'name': 'Gutt',
#   'name_eng': 'Boy',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '343',
#   'name': 'Jente',
#   'name_eng': 'Girl',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '380',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3913'},
#  {'depth': '1',
#   'id': '3916',
#   'name': 'Barnemøbler',
#   'name_eng': "Children's furniture",
#   'parent': '68'},
#  {'depth': '2',
#   'id': '314',
#   'name': 'Bord',
#   'name_eng': 'Table',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '315',
#   'name': 'Oppbevaring',
#   'name_eng': 'Storage',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '312',
#   'name': 'Senger',
#   'name_eng': 'Beds',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '316',
#   'name': 'Stellebord',
#   'name_eng': 'Changing table',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '313',
#   'name': 'Stoler',
#   'name_eng': 'Chairs',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '317',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3916'},
#  {'depth': '1',
#   'id': '3911',
#   'name': 'Barneseter',
#   'name_eng': 'Child seats',
#   'parent': '68'},
#  {'depth': '1',
#   'id': '3915',
#   'name': 'Barnesko',
#   'name_eng': "Children's shoes",
#   'parent': '68'},
#  {'depth': '2',
#   'id': '381',
#   'name': 'Baby',
#   'name_eng': 'Baby',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '382',
#   'name': 'Gutt',
#   'name_eng': 'Boy',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '383',
#   'name': 'Jente',
#   'name_eng': 'Girl',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '384',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3915'},
#  {'depth': '1',
#   'id': '3914',
#   'name': 'Barnevogner',
#   'name_eng': 'Prams',
#   'parent': '68'},
#  {'depth': '1',
#   'id': '3912',
#   'name': 'Leker',
#   'name_eng': 'Toys',
#   'parent': '68'},
#  {'depth': '2',
#   'id': '336',
#   'name': 'Andre leker',
#   'name_eng': 'Other toys',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '330',
#   'name': 'Babyleker',
#   'name_eng': 'Baby toys',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '331',
#   'name': 'Bamser, dukker og figurer',
#   'name_eng': 'Teddy bears, dolls and figurines',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '332',
#   'name': 'Biler og baner',
#   'name_eng': 'Cars and tracks',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '333',
#   'name': 'Lego og byggeklosser',
#   'name_eng': 'Lego and building blocks',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '334',
#   'name': 'Tegne- og formingsutstyr',
#   'name_eng': 'Drawing and shaping equipment',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '335',
#   'name': 'Uteleker',
#   'name_eng': 'Outdoor games',
#   'parent': '3912'},
#  {'depth': '1',
#   'id': '3948',
#   'name': 'Mammaklær',
#   'name_eng': 'Maternity clothes',
#   'parent': '68'},
#  {'depth': '1',
#   'id': '3918',
#   'name': 'Utstyr og sikkerhet',
#   'name_eng': 'Equipment and safety',
#   'parent': '68'},
#  {'depth': '1',
#   'id': '3970',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '68'},
#  {'depth': '0',
#   'id': '86',
#   'name': 'Fritid, hobby og underholdning',
#   'name_eng': 'Leisure, hobby and entertainment',
#   'parent': None},
#  {'depth': '1',
#   'id': '7735',
#   'name': 'Billetter og reiser',
#   'name_eng': 'Tickets and travel',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '113',
#   'name': 'Flybilletter',
#   'name_eng': 'Airline tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '116',
#   'name': 'Idrettsarrangementer',
#   'name_eng': 'Sports events',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '115',
#   'name': 'Konsertbilletter',
#   'name_eng': 'Concert tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '112',
#   'name': 'Pakkereiser',
#   'name_eng': 'Package tours',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '117',
#   'name': 'Teaterbilletter',
#   'name_eng': 'Theater tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '114',
#   'name': 'Togbilletter',
#   'name_eng': 'Train tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '118',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '7735'},
#  {'depth': '1',
#   'id': '5203',
#   'name': 'Brettspill og bordspill',
#   'name_eng': 'Board games and table games',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '122',
#   'name': 'Andre spill',
#   'name_eng': 'Other games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '120',
#   'name': 'Bordspill',
#   'name_eng': 'Board games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '119',
#   'name': 'Brettspill',
#   'name_eng': 'Board games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '121',
#   'name': 'Hage- og parkspill',
#   'name_eng': 'Garden and park games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '329',
#   'name': 'Puslespill',
#   'name_eng': 'Puzzle',
#   'parent': '5203'},
#  {'depth': '1',
#   'id': '5209',
#   'name': 'Bøker og blader',
#   'name_eng': 'Books and magazines',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '512',
#   'name': 'Blader og magasiner',
#   'name_eng': 'Magazines and magazines',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '513',
#   'name': 'Faglitteratur',
#   'name_eng': 'Nonfiction',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '520',
#   'name': 'Fakta og dokumentar',
#   'name_eng': 'Facts and documentary',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '94',
#   'name': 'Kokebøker',
#   'name_eng': 'Cookbooks',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '521',
#   'name': 'Oppslagsverk',
#   'name_eng': 'Reference book',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '514',
#   'name': 'Skjønnlitteratur',
#   'name_eng': 'Fiction',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '515',
#   'name': 'Tegneserier',
#   'name_eng': 'cartoons',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '97',
#   'name': 'Øvrige bøker og verk',
#   'name_eng': 'Other books and works',
#   'parent': '5209'},
#  {'depth': '1',
#   'id': '7734',
#   'name': 'Håndarbeid',
#   'name_eng': 'Handiwork',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '124',
#   'name': 'Garn',
#   'name_eng': 'Yarn',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '130',
#   'name': 'Keramikk',
#   'name_eng': 'Pottery',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '128',
#   'name': 'Maling og maleutstyr',
#   'name_eng': 'Paint and painting equipment',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '131',
#   'name': 'Perler og smykkestener',
#   'name_eng': 'Pearls and gemstones',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '129',
#   'name': 'Scrapbooking',
#   'name_eng': 'Scrapbooking',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '125',
#   'name': 'Stoff',
#   'name_eng': 'Fabric',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '126',
#   'name': 'Sy- og strikkeutstyr',
#   'name_eng': 'Sewing and knitting equipment',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '123',
#   'name': 'Symaskiner',
#   'name_eng': 'Sewing machines',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '132',
#   'name': 'Tresløyd',
#   'name_eng': 'Tree gutted',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '127',
#   'name': 'Vev',
#   'name_eng': 'Loom',
#   'parent': '7734'},
#  {'depth': '1',
#   'id': '3972',
#   'name': 'Mat og drikke',
#   'name_eng': 'Food and drink',
#   'parent': '86'},
#  {'depth': '1',
#   'id': '7732',
#   'name': 'Modellbyggesett og modeller',
#   'name_eng': 'Model building kits and models',
#   'parent': '86'},
#  {'depth': '1',
#   'id': '3922',
#   'name': 'Musikk og film',
#   'name_eng': 'Music and film',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '102',
#   'name': 'Blu-ray',
#   'name_eng': 'Blu-ray',
#   'parent': '3922'},
#  {'depth': '2', 'id': '98', 'name': 'CD', 'name_eng': 'CD', 'parent': '3922'},
#  {'depth': '2',
#   'id': '100',
#   'name': 'DVD',
#   'name_eng': 'DVD',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '402',
#   'name': 'Kassetter',
#   'name_eng': 'Cassettes',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '99',
#   'name': 'LP/EP',
#   'name_eng': 'LP/EP',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '101',
#   'name': 'VHS',
#   'name_eng': 'VHS',
#   'parent': '3922'},
#  {'depth': '1',
#   'id': '92',
#   'name': 'Musikkinstrumenter',
#   'name_eng': 'Musical instruments',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '106',
#   'name': 'Andre strengeinstrumenter',
#   'name_eng': 'Other stringed instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '296',
#   'name': 'Bassgitarer',
#   'name_eng': 'Bass guitars',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '295',
#   'name': 'Gitarer',
#   'name_eng': 'Guitars',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '110',
#   'name': 'Keyboard/synth',
#   'name_eng': 'Keyboard/synth',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '108',
#   'name': 'Lydutstyr',
#   'name_eng': 'Audio equipment',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '104',
#   'name': 'Messinginstrumenter',
#   'name_eng': 'Brass instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '337',
#   'name': 'Orgler',
#   'name_eng': 'Organs',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '109',
#   'name': 'Piano/flygel',
#   'name_eng': 'Piano/grand piano',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '107',
#   'name': 'Slagverk',
#   'name_eng': 'Percussion',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '105',
#   'name': 'Strykeinstrumenter',
#   'name_eng': 'String instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '103',
#   'name': 'Treblåsere',
#   'name_eng': 'Woodwinds',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '328',
#   'name': 'Trekkspill',
#   'name_eng': 'Accordion',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '111',
#   'name': 'Øvrige instrumenter',
#   'name_eng': 'Other instruments',
#   'parent': '92'},
#  {'depth': '1',
#   'id': '7733',
#   'name': 'RC-utstyr',
#   'name_eng': 'RC equipment',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '133',
#   'name': 'Bil',
#   'name_eng': 'Car',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '134',
#   'name': 'Båt',
#   'name_eng': 'Boat',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '401',
#   'name': 'Drone',
#   'name_eng': 'Drone',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '135',
#   'name': 'Fly',
#   'name_eng': 'Fly',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '136',
#   'name': 'Helikopter',
#   'name_eng': 'Helicopter',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '327',
#   'name': 'Modelljernbaner',
#   'name_eng': 'Model railways',
#   'parent': '7733'},
#  {'depth': '1',
#   'id': '285',
#   'name': 'Samleobjekter',
#   'name_eng': 'Collectibles',
#   'parent': '86'},
#  {'depth': '2',
#   'id': '141',
#   'name': 'Andre samlinger',
#   'name_eng': 'Other collections',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '137',
#   'name': 'Frimerker',
#   'name_eng': 'Stamps',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '399',
#   'name': 'Leker',
#   'name_eng': 'Toys',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '397',
#   'name': 'Militæreffekter',
#   'name_eng': 'Military effects',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '138',
#   'name': 'Mynter og sedler',
#   'name_eng': 'Coins and banknotes',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '139',
#   'name': 'Pins',
#   'name_eng': 'Pentecost',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '140',
#   'name': 'Postkort',
#   'name_eng': 'Postcard',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '400',
#   'name': 'Samlefigurer',
#   'name_eng': 'Collectible figures',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '396',
#   'name': 'Samlekort',
#   'name_eng': 'Trading cards',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '398',
#   'name': 'Skilt og plakater',
#   'name_eng': 'Signs and posters',
#   'parent': '285'},
#  {'depth': '1',
#   'id': '3973',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '86'},
#  {'depth': '0',
#   'id': '67',
#   'name': 'Hage, oppussing og hus',
#   'name_eng': 'Garden, renovation and house',
#   'parent': None},
#  {'depth': '1',
#   'id': '8347',
#   'name': 'Alarm og sikkerhet',
#   'name_eng': 'Alarm and security',
#   'parent': '67'},
#  {'depth': '1',
#   'id': '7749',
#   'name': 'Baderomsinnredning',
#   'name_eng': 'Bathroom furnishings',
#   'parent': '67'},
#  {'depth': '2',
#   'id': '157',
#   'name': 'Badekar',
#   'name_eng': 'Bathtub',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '164',
#   'name': 'Baderomsmøbler',
#   'name_eng': 'Bathroom furniture',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '158',
#   'name': 'Badstuer',
#   'name_eng': 'Saunas',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '156',
#   'name': 'Blandebatterier',
#   'name_eng': 'Mixer taps',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '160',
#   'name': 'Dusjkabinett og -vegger',
#   'name_eng': 'Shower enclosure and walls',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '162',
#   'name': 'Servanter',
#   'name_eng': 'Sinks',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '159',
#   'name': 'Steamdusjer',
#   'name_eng': 'Steam showers',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '163',
#   'name': 'Tilbehør',
#   'name_eng': 'Accessories',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '161',
#   'name': 'Toaletter',
#   'name_eng': 'Toilets',
#   'parent': '7749'},
#  {'depth': '1',
#   'id': '3899',
#   'name': 'Byggevarer og oppussing',
#   'name_eng': 'Building materials and renovation',
#   'parent': '67'},
#  {'depth': '2',
#   'id': '165',
#   'name': 'Andre byggevarer',
#   'name_eng': 'Other building materials',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '166',
#   'name': 'Byggesett',
#   'name_eng': 'Construction kit',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '169',
#   'name': 'Dører',
#   'name_eng': 'Doors',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '167',
#   'name': 'Gulv',
#   'name_eng': 'Floor',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '301',
#   'name': 'Tapet og maling',
#   'name_eng': 'Wallpaper and paint',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '346',
#   'name': 'Trapper',
#   'name_eng': 'Stairs',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '168',
#   'name': 'Vinduer',
#   'name_eng': 'Windows',
#   'parent': '3899'},
#  {'depth': '1',
#   'id': '8348',
#   'name': 'Garasje',
#   'name_eng': 'Garage',
#   'parent': '67'},
#  {'depth': '1',
#   'id': '3901',
#   'name': 'Hage og uteområder',
#   'name_eng': 'Garden and outdoor areas',
#   'parent': '67'},
#  {'depth': '2',
#   'id': '145',
#   'name': 'Annet hageutstyr',
#   'name_eng': 'Other garden equipment',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '339',
#   'name': 'Beplantning og tilbehør',
#   'name_eng': 'Planting and accessories',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '149',
#   'name': 'Gressklippere',
#   'name_eng': 'Lawnmowers',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '147',
#   'name': 'Grill',
#   'name_eng': 'Barbecue',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '142',
#   'name': 'Hagemøbler',
#   'name_eng': 'Garden furniture',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '143',
#   'name': 'Hageredskap',
#   'name_eng': 'Garden tools',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '146',
#   'name': 'Markiser og parasoller',
#   'name_eng': 'Awnings and parasols',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '144',
#   'name': 'Partytelt',
#   'name_eng': 'Party tent',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '148',
#   'name': 'Snørydding',
#   'name_eng': 'Snow removal',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '150',
#   'name': 'Svømmebasseng og spabad',
#   'name_eng': 'Swimming pool and hot tub',
#   'parent': '3901'},
#  {'depth': '1',
#   'id': '3968',
#   'name': 'Hytteutstyr',
#   'name_eng': 'Cabin equipment',
#   'parent': '67'},
#  {'depth': '1',
#   'id': '3900',
#   'name': 'Kjøkkeninnredning',
#   'name_eng': 'Kitchen furnishings',
#   'parent': '67'},
#  {'depth': '1',
#   'id': '5218',
#   'name': 'Oppvarming og ventilasjon',
#   'name_eng': 'Heating and ventilation',
#   'parent': '67'},
#  {'depth': '2',
#   'id': '297',
#   'name': 'Aircondition og vifter',
#   'name_eng': 'Air conditioning and fans',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '155',
#   'name': 'Elektriske ovner',
#   'name_eng': 'Electric ovens',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '151',
#   'name': 'Ovner',
#   'name_eng': 'Ovens',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '152',
#   'name': 'Peis',
#   'name_eng': 'Fireplace',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '154',
#   'name': 'Varmepumper',
#   'name_eng': 'Heat pumps',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '153',
#   'name': 'Ved og brensel',
#   'name_eng': 'Firewood and fuel',
#   'parent': '5218'},
#  {'depth': '1',
#   'id': '5219',
#   'name': 'Verktøy',
#   'name_eng': 'Tool',
#   'parent': '67'},
#  {'depth': '1',
#   'id': '3969',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '67'},
#  {'depth': '0',
#   'id': '71',
#   'name': 'Klær, kosmetikk og tilbehør',
#   'name_eng': 'Clothing, cosmetics and accessories',
#   'parent': None},
#  {'depth': '1',
#   'id': '8344',
#   'name': 'Briller og linser',
#   'name_eng': 'Glasses and lenses',
#   'parent': '71'},
#  {'depth': '2',
#   'id': '200',
#   'name': 'Briller',
#   'name_eng': 'Glasses',
#   'parent': '8344'},
#  {'depth': '2',
#   'id': '201',
#   'name': 'Linser',
#   'name_eng': 'Lentils',
#   'parent': '8344'},
#  {'depth': '2',
#   'id': '199',
#   'name': 'Solbriller',
#   'name_eng': 'Sunglasses',
#   'parent': '8344'},
#  {'depth': '1',
#   'id': '3941',
#   'name': 'Dameklær',
#   'name_eng': "Women's clothing",
#   'parent': '71'},
#  {'depth': '2',
#   'id': '171',
#   'name': 'Brudekjoler',
#   'name_eng': 'Wedding dresses',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '174',
#   'name': 'Bukser',
#   'name_eng': 'Pants',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '170',
#   'name': 'Bunader',
#   'name_eng': 'Bunader',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '177',
#   'name': 'Gensere',
#   'name_eng': 'Sweaters',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '178',
#   'name': 'Jakker',
#   'name_eng': 'Jackets',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '172',
#   'name': 'Kjoler',
#   'name_eng': 'Dresses',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '310',
#   'name': 'Luer, skjerf og votter',
#   'name_eng': 'Hats, scarves and mittens',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '180',
#   'name': 'Skjorter',
#   'name_eng': 'Shirts',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '175',
#   'name': 'Skjørt',
#   'name_eng': 'Skirt',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '179',
#   'name': 'T-skjorter',
#   'name_eng': 'T shirts',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '176',
#   'name': 'Topper',
#   'name_eng': 'Tops',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '181',
#   'name': 'Undertøy',
#   'name_eng': 'Underwear',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '173',
#   'name': 'Ytterklær',
#   'name_eng': 'Outerwear',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '182',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3941'},
#  {'depth': '1',
#   'id': '3950',
#   'name': 'Herreklær',
#   'name_eng': "Men's clothing",
#   'parent': '71'},
#  {'depth': '2',
#   'id': '184',
#   'name': 'Bukser',
#   'name_eng': 'Pants',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '188',
#   'name': 'Bunader',
#   'name_eng': 'Bunader',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '189',
#   'name': 'Dresser',
#   'name_eng': 'Suits',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '186',
#   'name': 'Gensere',
#   'name_eng': 'Sweaters',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '311',
#   'name': 'Luer, skjerf og votter',
#   'name_eng': 'Hats, scarves and mittens',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '185',
#   'name': 'Skjorter',
#   'name_eng': 'Shirts',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '190',
#   'name': 'Smokinger',
#   'name_eng': 'Tuxedos',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '187',
#   'name': 'T-skjorter',
#   'name_eng': 'T shirts',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '191',
#   'name': 'Undertøy',
#   'name_eng': 'Underwear',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '183',
#   'name': 'Ytterklær',
#   'name_eng': 'Outerwear',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '192',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3950'},
#  {'depth': '1',
#   'id': '8280',
#   'name': 'Hud-, hår- og kroppspleie',
#   'name_eng': 'Skin, hair and body care',
#   'parent': '71'},
#  {'depth': '1',
#   'id': '3945',
#   'name': 'Klokker og ur',
#   'name_eng': 'Clocks and watches',
#   'parent': '71'},
#  {'depth': '1',
#   'id': '8282',
#   'name': 'Kosmetikk',
#   'name_eng': 'Cosmetics',
#   'parent': '71'},
#  {'depth': '1',
#   'id': '8349',
#   'name': 'Kostyme',
#   'name_eng': 'Costume',
#   'parent': '71'},
#  {'depth': '1',
#   'id': '3949',
#   'name': 'Sko',
#   'name_eng': 'Shoe',
#   'parent': '71'},
#  {'depth': '2',
#   'id': '194',
#   'name': 'Damesko',
#   'name_eng': "Women's shoes",
#   'parent': '3949'},
#  {'depth': '2',
#   'id': '193',
#   'name': 'Herresko',
#   'name_eng': "Men's shoes",
#   'parent': '3949'},
#  {'depth': '1',
#   'id': '7748',
#   'name': 'Smykker og oppbevaring',
#   'name_eng': 'Jewelery and storage',
#   'parent': '71'},
#  {'depth': '2',
#   'id': '306',
#   'name': 'Andre smykker',
#   'name_eng': 'Other jewelry',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '198',
#   'name': 'Armbånd',
#   'name_eng': 'Bracelet',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '195',
#   'name': 'Halskjeder',
#   'name_eng': 'Necklaces',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '196',
#   'name': 'Ringer',
#   'name_eng': 'Calls',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '307',
#   'name': 'Smykkeskrin og oppbevaring',
#   'name_eng': 'Jewelery box and storage',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '197',
#   'name': 'Ørepynt',
#   'name_eng': 'Earrings',
#   'parent': '7748'},
#  {'depth': '1',
#   'id': '3946',
#   'name': 'Vesker og bager',
#   'name_eng': 'Bags and bags',
#   'parent': '71'},
#  {'depth': '1',
#   'id': '5204',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '71'},
#  {'depth': '0',
#   'id': '78',
#   'name': 'Møbler og interiør',
#   'name_eng': 'Furniture and interiors',
#   'parent': None},
#  {'depth': '1',
#   'id': '5181',
#   'name': 'Belysning',
#   'name_eng': 'Lighting',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '230',
#   'name': 'Andre lamper',
#   'name_eng': 'Other lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '229',
#   'name': 'Bordlamper',
#   'name_eng': 'Table lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '228',
#   'name': 'Stålamper',
#   'name_eng': 'Steel lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '226',
#   'name': 'Taklamper',
#   'name_eng': 'Ceiling lights',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '227',
#   'name': 'Vegglamper',
#   'name_eng': 'Wall lamps',
#   'parent': '5181'},
#  {'depth': '1',
#   'id': '5196',
#   'name': 'Bord og stoler',
#   'name_eng': 'Table and chairs',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '217',
#   'name': 'Andre bord og stoler',
#   'name_eng': 'Other tables and chairs',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '213',
#   'name': 'Kjøkkenbord',
#   'name_eng': 'Kitchen table',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '215',
#   'name': 'Kontorstoler',
#   'name_eng': 'Office chairs',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '212',
#   'name': 'Salongbord',
#   'name_eng': 'Coffee table',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '214',
#   'name': 'Skrivebord',
#   'name_eng': 'Desk',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '211',
#   'name': 'Spisestuer',
#   'name_eng': 'Dining rooms',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '216',
#   'name': 'Stoler og krakker',
#   'name_eng': 'Chairs and stools',
#   'parent': '5196'},
#  {'depth': '1',
#   'id': '5222',
#   'name': 'Dekorasjon og pyntegjenstander',
#   'name_eng': 'Decoration and ornaments',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '241',
#   'name': 'Andre pyntgjenstander',
#   'name_eng': 'Other decorative items',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '237',
#   'name': 'Bilder og rammer',
#   'name_eng': 'Pictures and frames',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '239',
#   'name': 'Fat',
#   'name_eng': 'Barrel',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '240',
#   'name': 'Lysestaker',
#   'name_eng': 'Candlesticks',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '299',
#   'name': 'Speil',
#   'name_eng': 'Mirror',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '238',
#   'name': 'Vaser',
#   'name_eng': 'Vases',
#   'parent': '5222'},
#  {'depth': '1',
#   'id': '5198',
#   'name': 'Garderobe og skap',
#   'name_eng': 'Wardrobe and closet',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '218',
#   'name': 'Garderober',
#   'name_eng': 'Wardrobes',
#   'parent': '5198'},
#  {'depth': '2',
#   'id': '222',
#   'name': 'Seksjoner',
#   'name_eng': 'Sections',
#   'parent': '5198'},
#  {'depth': '2',
#   'id': '225',
#   'name': 'Skap',
#   'name_eng': 'Cabinet',
#   'parent': '5198'},
#  {'depth': '1',
#   'id': '8345',
#   'name': 'Hyller og kommoder',
#   'name_eng': 'Shelves and chests of drawers',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '219',
#   'name': 'Hyller',
#   'name_eng': 'Shelves',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '221',
#   'name': 'Kommoder',
#   'name_eng': 'Chest of drawers',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '223',
#   'name': 'Nattbord',
#   'name_eng': 'Bedside table',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '220',
#   'name': 'Skjenk',
#   'name_eng': 'Sideboard',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '224',
#   'name': 'TV-møbler',
#   'name_eng': 'TV furniture',
#   'parent': '8345'},
#  {'depth': '1',
#   'id': '5223',
#   'name': 'Kjøkkenutstyr og serviser',
#   'name_eng': 'Kitchen equipment and crockery',
#   'parent': '78'},
#  {'depth': '1',
#   'id': '5197',
#   'name': 'Senger og madrasser',
#   'name_eng': 'Beds and mattresses',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '203',
#   'name': 'Madrasser',
#   'name_eng': 'Mattresses',
#   'parent': '5197'},
#  {'depth': '2',
#   'id': '293',
#   'name': 'Rammemadrasser',
#   'name_eng': 'Frame mattresses',
#   'parent': '5197'},
#  {'depth': '2',
#   'id': '202',
#   'name': 'Senger',
#   'name_eng': 'Beds',
#   'parent': '5197'},
#  {'depth': '1',
#   'id': '7756',
#   'name': 'Sofaer og lenestoler',
#   'name_eng': 'Sofas and armchairs',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '204',
#   'name': '2-seter',
#   'name_eng': '2-seater',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '205',
#   'name': '3-seter',
#   'name_eng': '3-seater',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '207',
#   'name': 'Hjørnesofaer',
#   'name_eng': 'Corner sofas',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '210',
#   'name': 'Lenestoler',
#   'name_eng': 'Armchairs',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '209',
#   'name': 'Puffer',
#   'name_eng': 'Poufs',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '208',
#   'name': 'Sofagrupper',
#   'name_eng': 'Sofa groups',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '206',
#   'name': 'Sovesofaer',
#   'name_eng': 'Sofa beds',
#   'parent': '7756'},
#  {'depth': '1',
#   'id': '5180',
#   'name': 'Tepper og tekstiler',
#   'name_eng': 'Carpets and textiles',
#   'parent': '78'},
#  {'depth': '2',
#   'id': '235',
#   'name': 'Andre tekstiler',
#   'name_eng': 'Other textiles',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '233',
#   'name': 'Duker',
#   'name_eng': 'Tablecloths',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '234',
#   'name': 'Gardiner',
#   'name_eng': 'Curtains',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '232',
#   'name': 'Puter',
#   'name_eng': 'Pillows',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '231',
#   'name': 'Tepper',
#   'name_eng': 'Carpets',
#   'parent': '5180'},
#  {'depth': '1',
#   'id': '3971',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '78'},
#  {'depth': '0',
#   'id': '91',
#   'name': 'Næringsvirksomhet',
#   'name_eng': 'Commercial activities',
#   'parent': None},
#  {'depth': '1',
#   'id': '3108',
#   'name': 'Butikk og varehandel',
#   'name_eng': 'Shop and retail',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '364',
#   'name': 'Annet butikkutstyr',
#   'name_eng': 'Other shop equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '358',
#   'name': 'Betalingsutstyr',
#   'name_eng': 'Payment equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '362',
#   'name': 'Butikkbelysning',
#   'name_eng': 'Shop lighting',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '359',
#   'name': 'Butikkinnredning',
#   'name_eng': 'Shop furnishings',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '361',
#   'name': 'Lagerutstyr',
#   'name_eng': 'Storage equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '360',
#   'name': 'Sikkerhet og overvåkning',
#   'name_eng': 'Security and monitoring',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '363',
#   'name': 'Vareparti og konkursbo',
#   'name_eng': 'Goods lot and bankruptcy estate',
#   'parent': '3108'},
#  {'depth': '1',
#   'id': '3111',
#   'name': 'Container og brakker',
#   'name_eng': 'Containers and barracks',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '368',
#   'name': 'Annet anleggsutstyr',
#   'name_eng': 'Other construction equipment',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '366',
#   'name': 'Brakker',
#   'name_eng': 'Barracks',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '365',
#   'name': 'Containere',
#   'name_eng': 'Containers',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '367',
#   'name': 'Mannskapsvogner',
#   'name_eng': 'Crew cars',
#   'parent': '3111'},
#  {'depth': '1',
#   'id': '8343',
#   'name': 'Helse og behandling',
#   'name_eng': 'Health and treatment',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '357',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '347',
#   'name': 'Førstehjelpsutstyr',
#   'name_eng': 'First aid equipment',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '348',
#   'name': 'Hjelpemidler',
#   'name_eng': 'Aids',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '349',
#   'name': 'Hud- og kroppspleie',
#   'name_eng': 'Skin and body care',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '350',
#   'name': 'Utstyr og inventar',
#   'name_eng': 'Equipment and inventory',
#   'parent': '8343'},
#  {'depth': '1',
#   'id': '3105',
#   'name': 'Kontorutstyr og innredning',
#   'name_eng': 'Office equipment and furnishings',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '294',
#   'name': 'Innredning',
#   'name_eng': 'Furnishing',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '243',
#   'name': 'Kopimaskiner',
#   'name_eng': 'Copy machines',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '244',
#   'name': 'Printere',
#   'name_eng': 'Printers',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '242',
#   'name': 'Rekvisita',
#   'name_eng': 'Props',
#   'parent': '3105'},
#  {'depth': '1',
#   'id': '3114',
#   'name': 'Landbruk',
#   'name_eng': 'Agriculture',
#   'parent': '91'},
#  {'depth': '1',
#   'id': '3113',
#   'name': 'Last og transport',
#   'name_eng': 'Load and transport',
#   'parent': '91'},
#  {'depth': '1',
#   'id': '3112',
#   'name': 'Maskinutstyr og reservedeler',
#   'name_eng': 'Machine equipment and spare parts',
#   'parent': '91'},
#  {'depth': '1',
#   'id': '3115',
#   'name': 'Resirkulering og returavfall',
#   'name_eng': 'Recycling and return waste',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '403',
#   'name': 'Havplast',
#   'name_eng': 'Marine plastic',
#   'parent': '3115'},
#  {'depth': '1',
#   'id': '3110',
#   'name': 'Scene',
#   'name_eng': 'Stage',
#   'parent': '91'},
#  {'depth': '1',
#   'id': '3103',
#   'name': 'Storkjøkken og restaurant',
#   'name_eng': 'Commercial kitchen and restaurant',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '356',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '355',
#   'name': 'Innredning',
#   'name_eng': 'Furnishing',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '351',
#   'name': 'Kjøkkenutstyr',
#   'name_eng': 'Kitchen equipment',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '352',
#   'name': 'Kjøl og frys',
#   'name_eng': 'Refrigerate and freeze',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '353',
#   'name': 'Koke- og stekeprodukter',
#   'name_eng': 'Cooking and baking products',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '354',
#   'name': 'Oppvask',
#   'name_eng': 'Dishwashing',
#   'parent': '3103'},
#  {'depth': '1',
#   'id': '3102',
#   'name': 'Verksted, bygg og anlegg',
#   'name_eng': 'Workshop, building and construction',
#   'parent': '91'},
#  {'depth': '2',
#   'id': '379',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '372',
#   'name': 'Byggtørkere',
#   'name_eng': 'Building dryers',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '373',
#   'name': 'Kompressor',
#   'name_eng': 'Compressor',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '378',
#   'name': 'Lagerhall',
#   'name_eng': 'Warehouse',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '371',
#   'name': 'Lys',
#   'name_eng': 'Light',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '377',
#   'name': 'Maskiner og utstyr',
#   'name_eng': 'Machinery and equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '376',
#   'name': 'Maskinutleie',
#   'name_eng': 'Machine rental',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '374',
#   'name': 'Stillas og reoler',
#   'name_eng': 'Scaffolding and shelving',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '375',
#   'name': 'Treforedling',
#   'name_eng': 'Wood processing',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '370',
#   'name': 'Verkstedsutstyr',
#   'name_eng': 'Workshop equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '369',
#   'name': 'Verktøy',
#   'name_eng': 'Tool',
#   'parent': '3102'},
#  {'depth': '1',
#   'id': '3106',
#   'name': 'Webdomener og gullnummer',
#   'name_eng': 'Web domains and gold numbers',
#   'parent': '91'},
#  {'depth': '1',
#   'id': '3104',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '91'},
#  {'depth': '0',
#   'id': '69',
#   'name': 'Sport og friluftsliv',
#   'name_eng': 'Sports and outdoor life',
#   'parent': None},
#  {'depth': '1',
#   'id': '3966',
#   'name': 'Annen sport',
#   'name_eng': 'Other sports',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '3961',
#   'name': 'Ballsport',
#   'name_eng': 'Ball sports',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '251',
#   'name': 'Annen ballsport',
#   'name_eng': 'Other ball sports',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '250',
#   'name': 'Bandy',
#   'name_eng': 'Bandy',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '247',
#   'name': 'Basketball',
#   'name_eng': 'Basketball',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '245',
#   'name': 'Fotball',
#   'name_eng': 'Soccer',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '246',
#   'name': 'Håndball',
#   'name_eng': 'handball',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '249',
#   'name': 'Tennis',
#   'name_eng': 'Tennis',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '248',
#   'name': 'Volleyball',
#   'name_eng': 'Volleyball',
#   'parent': '3961'},
#  {'depth': '1',
#   'id': '3938',
#   'name': 'Ekstremsport',
#   'name_eng': 'Extreme sports',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '266',
#   'name': 'Fallskjermhopping',
#   'name_eng': 'Skydiving',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '264',
#   'name': 'Kiting',
#   'name_eng': 'Kiting',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '265',
#   'name': 'Klatring',
#   'name_eng': 'Climbing',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '267',
#   'name': 'Skate- og longboard',
#   'name_eng': 'Skate and longboard',
#   'parent': '3938'},
#  {'depth': '1',
#   'id': '3967',
#   'name': 'GPS og pulsklokker',
#   'name_eng': 'GPS and heart rate monitors',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '5164',
#   'name': 'Golf',
#   'name_eng': 'Golf',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '3964',
#   'name': 'Jakt, fiske og friluftsliv',
#   'name_eng': 'Hunting, fishing and outdoor activities',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '275',
#   'name': 'Annet fiskeutstyr',
#   'name_eng': 'Other fishing equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '270',
#   'name': 'Annet jaktutstyr',
#   'name_eng': 'Other hunting equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '280',
#   'name': 'Annet turutstyr',
#   'name_eng': 'Other hiking equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '274',
#   'name': 'Fiskeklær',
#   'name_eng': 'Fishing clothes',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '271',
#   'name': 'Fiskestenger',
#   'name_eng': 'Fishing rods',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '269',
#   'name': 'Jaktklær',
#   'name_eng': 'Hunting clothes',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '279',
#   'name': 'Kano',
#   'name_eng': 'Canoe',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '300',
#   'name': 'Kikkerter og optikk',
#   'name_eng': 'Binoculars and optics',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '278',
#   'name': 'Ryggsekker',
#   'name_eng': 'Backpacks',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '273',
#   'name': 'Sneller, fluer og kroker',
#   'name_eng': 'Reels, flies and hooks',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '276',
#   'name': 'Soveposer',
#   'name_eng': 'Sleeping bags',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '272',
#   'name': 'Teiner og garn',
#   'name_eng': 'Twine and yarn',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '277',
#   'name': 'Telt',
#   'name_eng': 'Tent',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '268',
#   'name': 'Våpen',
#   'name_eng': 'Arms',
#   'parent': '3964'},
#  {'depth': '1',
#   'id': '8281',
#   'name': 'Kosttilskudd',
#   'name_eng': 'Dietary supplements',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '3962',
#   'name': 'Skisport',
#   'name_eng': 'Skiing',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '253',
#   'name': 'Alpint',
#   'name_eng': 'Alpine',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '256',
#   'name': 'Annet skiutstyr',
#   'name_eng': 'Other ski equipment',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '255',
#   'name': 'Langrenn',
#   'name_eng': 'Cross-country skiing',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '252',
#   'name': 'Snowboard',
#   'name_eng': 'Snowboarding',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '254',
#   'name': 'Telemark',
#   'name_eng': 'Telemark',
#   'parent': '3962'},
#  {'depth': '1',
#   'id': '8346',
#   'name': 'Skøytesport',
#   'name_eng': 'Ice skating',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '405',
#   'name': 'Skøyter til barn',
#   'name_eng': 'Skates for children',
#   'parent': '8346'},
#  {'depth': '2',
#   'id': '404',
#   'name': 'Skøyter til voksne',
#   'name_eng': 'Skates for adults',
#   'parent': '8346'},
#  {'depth': '2',
#   'id': '406',
#   'name': 'Skøyteutstyr',
#   'name_eng': 'Skating equipment',
#   'parent': '8346'},
#  {'depth': '1',
#   'id': '3940',
#   'name': 'Sportsklær og sko',
#   'name_eng': 'Sportswear and shoes',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '3983',
#   'name': 'Barneklær',
#   'name_eng': "Children's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3981',
#   'name': 'Dameklær',
#   'name_eng': "Women's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3980',
#   'name': 'Herreklær',
#   'name_eng': "Men's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3984',
#   'name': 'Sko',
#   'name_eng': 'Shoe',
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3982',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3940'},
#  {'depth': '1',
#   'id': '3965',
#   'name': 'Sportsskyting',
#   'name_eng': 'Sports shooting',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '284',
#   'name': 'Luftvåpen',
#   'name_eng': 'Air weapons',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '281',
#   'name': 'Paintball',
#   'name_eng': 'Paintball',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '282',
#   'name': 'Pistol',
#   'name_eng': 'Pistol',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '283',
#   'name': 'Softgun',
#   'name_eng': 'Softgun',
#   'parent': '3965'},
#  {'depth': '1',
#   'id': '3960',
#   'name': 'Startnummer',
#   'name_eng': 'Start number',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '3937',
#   'name': 'Supporterutstyr',
#   'name_eng': 'Supporter equipment',
#   'parent': '69'},
#  {'depth': '1',
#   'id': '3963',
#   'name': 'Sykkelsport',
#   'name_eng': 'Cycling',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '257',
#   'name': 'Sykler',
#   'name_eng': 'Bicycles',
#   'parent': '3963'},
#  {'depth': '2',
#   'id': '258',
#   'name': 'Utstyr',
#   'name_eng': 'Equipment',
#   'parent': '3963'},
#  {'depth': '1',
#   'id': '5166',
#   'name': 'Treningsapparater og -utstyr',
#   'name_eng': 'Exercise apparatus and equipment',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '291',
#   'name': 'Ellipsemaskiner',
#   'name_eng': 'Elliptical machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '287',
#   'name': 'Romaskiner',
#   'name_eng': 'Rowing machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '290',
#   'name': 'Stepmaskiner',
#   'name_eng': 'Step machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '288',
#   'name': 'Styrkeapparater',
#   'name_eng': 'Strength equipment',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '516',
#   'name': 'Tredemøller',
#   'name_eng': 'Treadmills',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '286',
#   'name': 'Treningssykler',
#   'name_eng': 'Exercise bikes',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '289',
#   'name': 'Treningsutstyr',
#   'name_eng': 'Training equipment',
#   'parent': '5166'},
#  {'depth': '1',
#   'id': '7738',
#   'name': 'Vannsport',
#   'name_eng': 'Water sports',
#   'parent': '69'},
#  {'depth': '2',
#   'id': '263',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '259',
#   'name': 'Dykking',
#   'name_eng': 'Diving',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '260',
#   'name': 'Padling',
#   'name_eng': 'Paddling',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '261',
#   'name': 'Seiling',
#   'name_eng': 'Sailing',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '262',
#   'name': 'Surfing',
#   'name_eng': 'Surfing',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '338',
#   'name': 'Windsurf',
#   'name_eng': 'Windsurfing',
#   'parent': '7738'},
#  {'depth': '0',
#   'id': '90',
#   'name': 'Utstyr til bil, båt og MC',
#   'name_eng': 'Equipment for car, boat and motorbike',
#   'parent': None},
#  {'depth': '1',
#   'id': '3975',
#   'name': 'ATV-deler',
#   'name_eng': 'ATV parts',
#   'parent': '90'},
#  {'depth': '1',
#   'id': '82',
#   'name': 'Bildeler',
#   'name_eng': 'Car parts',
#   'parent': '90'},
#  {'depth': '2',
#   'id': '9',
#   'name': 'Annet biltilbehør',
#   'name_eng': 'Other car accessories',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '2',
#   'name': 'Bildeler',
#   'name_eng': 'Car parts',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '3',
#   'name': 'Bilseter',
#   'name_eng': 'Car seats',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '5',
#   'name': 'Bilstereo',
#   'name_eng': 'Car stereo',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '6',
#   'name': 'Dekk og felger',
#   'name_eng': 'Tires and rims',
#   'parent': '82'},
#  {'depth': '2', 'id': '344', 'name': 'GPS', 'name_eng': 'GPS', 'parent': '82'},
#  {'depth': '2',
#   'id': '8',
#   'name': 'Styling',
#   'name_eng': 'Styling',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '4',
#   'name': 'Takstativ og boks',
#   'name_eng': 'Roof rack and box',
#   'parent': '82'},
#  {'depth': '1',
#   'id': '30',
#   'name': 'Båtdeler',
#   'name_eng': 'Boat parts',
#   'parent': '90'},
#  {'depth': '2',
#   'id': '325',
#   'name': 'Annet båtutstyr',
#   'name_eng': 'Other boat equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '318',
#   'name': 'Elektronikk',
#   'name_eng': 'Electronics',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '324',
#   'name': 'Fortøyningsutstyr',
#   'name_eng': 'Mooring equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '320',
#   'name': 'Interiør og eksteriør',
#   'name_eng': 'Interior and exterior',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '340',
#   'name': 'Motordeler',
#   'name_eng': 'Engine parts',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '345',
#   'name': 'Navigasjon',
#   'name_eng': 'Navigation',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '323',
#   'name': 'Seilbåtutstyr',
#   'name_eng': 'Sailboat equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '322',
#   'name': 'Sikkerhet',
#   'name_eng': 'Safety',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '319',
#   'name': 'Strøm og VVS',
#   'name_eng': 'Electricity and plumbing',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '321',
#   'name': 'Styring og vinsj',
#   'name_eng': 'Steering and winch',
#   'parent': '30'},
#  {'depth': '1',
#   'id': '70',
#   'name': 'Caravandeler',
#   'name_eng': 'Caravan parts',
#   'parent': '90'},
#  {'depth': '1',
#   'id': '20',
#   'name': 'MC-deler',
#   'name_eng': 'MC parts',
#   'parent': '90'},
#  {'depth': '2',
#   'id': '10',
#   'name': 'MC-deler',
#   'name_eng': 'MC parts',
#   'parent': '20'},
#  {'depth': '2',
#   'id': '12',
#   'name': 'MC-klær',
#   'name_eng': 'MC clothing',
#   'parent': '20'},
#  {'depth': '2',
#   'id': '11',
#   'name': 'MC-tilbehør',
#   'name_eng': 'MC accessories',
#   'parent': '20'},
#  {'depth': '1',
#   'id': '80',
#   'name': 'Tilhengere',
#   'name_eng': 'Followers',
#   'parent': '90'},
#  {'depth': '2',
#   'id': '16',
#   'name': 'ATV- og MC-hengere',
#   'name_eng': 'ATV and MC trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '17',
#   'name': 'Biltransporthengere',
#   'name_eng': 'Car transport trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '14',
#   'name': 'Båt- og opplagshengere',
#   'name_eng': 'Boat and storage trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '19',
#   'name': 'Hestehengere',
#   'name_eng': 'Horse trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '18',
#   'name': 'Maskinhengere',
#   'name_eng': 'Machine trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '15',
#   'name': 'Skaphengere',
#   'name_eng': 'Closet hangers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '517',
#   'name': 'Termohengere',
#   'name_eng': 'Thermal hangers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '308',
#   'name': 'Tilhengertilbehør',
#   'name_eng': 'Trailer accessories',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '309',
#   'name': 'Tipphengere',
#   'name_eng': 'Tipper trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '13',
#   'name': 'Varehengere',
#   'name_eng': 'Goods trailers',
#   'parent': '80'},
#  {'depth': '1',
#   'id': '3974',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '90'}]

# %%
import json


def save_json(obj, filename):
    with open(filename, "w") as f:
        json.dump(obj, f, indent=4)


save_json(found_categories, "finn_categories.json")

# %%
import json

def load_json(filename):
    with open(filename, "r") as f:
        return json.load(f)

finn_categories = load_json("finn_categories.json")

# %%
def sort_categories(categories):
    main = [c for c in categories if c["depth"] == "0"]
    sub = [c for c in categories if c["depth"] == "1"]
    product = [c for c in categories if c["depth"] == "2"]
    return main, sub, product


main_categories, sub_categories, product_categories = sort_categories(finn_categories)

pprint(product_categories)
# Out:
# [{'depth': '2',
#   'id': '385',
#   'name': 'Akryl',
#   'name_eng': 'Acrylic',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '386',
#   'name': 'Akvarell',
#   'name_eng': 'Watercolor',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '395',
#   'name': 'Annen kunst',
#   'name_eng': 'Other art',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '387',
#   'name': 'Blandingsteknikker',
#   'name_eng': 'Mixing techniques',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '388',
#   'name': 'Fotografi',
#   'name_eng': 'Photograph',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '389',
#   'name': 'Litografi',
#   'name_eng': 'Lithography',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '390',
#   'name': 'Oljemaleri',
#   'name_eng': 'Oil painting',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '391',
#   'name': 'Skulptur',
#   'name_eng': 'Sculpture',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '392',
#   'name': 'Tegning',
#   'name_eng': 'Drawing',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '393',
#   'name': 'Tresnitt',
#   'name_eng': 'Woodcut',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '394',
#   'name': 'Trykk',
#   'name_eng': 'Press',
#   'parent': '5177'},
#  {'depth': '2',
#   'id': '36',
#   'name': 'Kaldblodshester',
#   'name_eng': 'Cold-blooded horses',
#   'parent': '5190'},
#  {'depth': '2',
#   'id': '37',
#   'name': 'Ponnier',
#   'name_eng': 'Ponies',
#   'parent': '5190'},
#  {'depth': '2',
#   'id': '38',
#   'name': 'Varmblodshester',
#   'name_eng': 'Warmblood horses',
#   'parent': '5190'},
#  {'depth': '2',
#   'id': '21',
#   'name': 'Apporterende hunder',
#   'name_eng': 'Fetching dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '22',
#   'name': 'Blandingshunder',
#   'name_eng': 'Mixed breed dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '23',
#   'name': 'Bruks-, hyrde- og gjeterhunder',
#   'name_eng': 'Working, herding and herding dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '24',
#   'name': 'Dachs-, drivende og sporhunder',
#   'name_eng': 'Dachshund, driving and tracking dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '25',
#   'name': 'Mynder',
#   'name_eng': 'Figures',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '26',
#   'name': 'Pinscher-, schnauzer-, molosser og sennenhunder',
#   'name_eng': 'Pinschers, schnauzers, molossers and mountain dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '27',
#   'name': 'Selskapshunder',
#   'name_eng': 'Companion dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '28',
#   'name': 'Spisshunder',
#   'name_eng': 'Spitz dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '29',
#   'name': 'Stående fuglehunder',
#   'name_eng': 'Standing bird dogs',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '501',
#   'name': 'Terriere',
#   'name_eng': 'Terriers',
#   'parent': '5192'},
#  {'depth': '2',
#   'id': '31',
#   'name': 'Blandingskatter',
#   'name_eng': 'Mixed taxes',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '32',
#   'name': 'Korthåret',
#   'name_eng': 'The short hair',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '33',
#   'name': 'Orientalere',
#   'name_eng': 'Orientals',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '34',
#   'name': 'Persere',
#   'name_eng': 'Persians',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '35',
#   'name': 'Semi-langhåret',
#   'name_eng': 'Semi-long haired',
#   'parent': '5191'},
#  {'depth': '2',
#   'id': '43',
#   'name': 'Bærbar PC',
#   'name_eng': 'Laptop',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '46',
#   'name': 'Datatilbehør',
#   'name_eng': 'Computer accessories',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '47',
#   'name': 'Kalkulatorer',
#   'name_eng': 'Calculators',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '49',
#   'name': 'Programvare',
#   'name_eng': 'Software',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '45',
#   'name': 'Skjermer',
#   'name_eng': 'Screens',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '44',
#   'name': 'Stasjonær PC',
#   'name_eng': 'Stationary PC',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '48',
#   'name': 'Tablet og lesebrett',
#   'name_eng': 'Tablet and reading board',
#   'parent': '3215'},
#  {'depth': '2',
#   'id': '505',
#   'name': 'Annet fotoutstyr',
#   'name_eng': 'Other photo equipment',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '500',
#   'name': 'Fotovesker og -bager',
#   'name_eng': 'Photo bags and backpacks',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '303',
#   'name': 'Hybridkamera',
#   'name_eng': 'Hybrid camera',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '502',
#   'name': 'Kompaktkameraer',
#   'name_eng': 'Compact cameras',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '503',
#   'name': 'Objektiver',
#   'name_eng': 'Objectives',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '66',
#   'name': 'Systemkameraer',
#   'name_eng': 'System cameras',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '504',
#   'name': 'Videokameraer',
#   'name_eng': 'Video cameras',
#   'parent': '3904'},
#  {'depth': '2',
#   'id': '304',
#   'name': 'Andre apparater',
#   'name_eng': 'Other appliances',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '83',
#   'name': 'Blender',
#   'name_eng': 'Blender',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '87',
#   'name': 'Brødrister',
#   'name_eng': 'Toaster',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '506',
#   'name': 'Kaffemaskin',
#   'name_eng': 'Coffee machine',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '507',
#   'name': 'Kjøkkenmaskin og foodprosessor',
#   'name_eng': 'Kitchen machine and food processor',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '89',
#   'name': 'Miksere',
#   'name_eng': 'Mixers',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '84',
#   'name': 'Strykejern',
#   'name_eng': 'Iron',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '81',
#   'name': 'Støvsuger',
#   'name_eng': 'Vacuum cleaner',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '88',
#   'name': 'Vaffel- og toastjern',
#   'name_eng': 'Waffle and toast iron',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '85',
#   'name': 'Vannkoker',
#   'name_eng': 'Kettle',
#   'parent': '3216'},
#  {'depth': '2',
#   'id': '305',
#   'name': 'Andre hvitevarer',
#   'name_eng': 'Other white goods',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '72',
#   'name': 'Frysere',
#   'name_eng': 'Freezers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '74',
#   'name': 'Innbyggingsovner',
#   'name_eng': 'Built-in ovens',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '292',
#   'name': 'Kjøleskap',
#   'name_eng': 'Refrigerator',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '73',
#   'name': 'Komfyrer',
#   'name_eng': 'Stoves',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '508',
#   'name': 'Mikrobølgeovner',
#   'name_eng': 'Microwave ovens',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '509',
#   'name': 'Oppvaskmaskiner',
#   'name_eng': 'Dishwashers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '75',
#   'name': 'Platetopper',
#   'name_eng': 'Plate tops',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '510',
#   'name': 'Tørketromler',
#   'name_eng': 'Tumble dryers',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '79',
#   'name': 'Vaskemaskiner',
#   'name_eng': 'Washing machines',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '511',
#   'name': 'Ventilatorer',
#   'name_eng': 'Ventilators',
#   'parent': '3907'},
#  {'depth': '2',
#   'id': '56',
#   'name': 'Bluray-spillere',
#   'name_eng': 'Bluray players',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '57',
#   'name': 'DVD-spillere',
#   'name_eng': 'DVD players',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '61',
#   'name': 'Digital-TV og mediabokser',
#   'name_eng': 'Digital TV and media boxes',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '52',
#   'name': 'Forsterkere og receivere',
#   'name_eng': 'Amplifiers and receivers',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '59',
#   'name': 'Hjemmekinoanlegg',
#   'name_eng': 'Home cinema system',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '51',
#   'name': 'Hodetelefoner',
#   'name_eng': 'Headphones',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '53',
#   'name': 'Høyttalere',
#   'name_eng': 'Speakers',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '326',
#   'name': 'Kabler og tilbehør',
#   'name_eng': 'Cables and accessories',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '50',
#   'name': 'MP3 og bærbar lyd',
#   'name_eng': 'MP3 and portable audio',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '54',
#   'name': 'PA-utstyr',
#   'name_eng': 'PA equipment',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '60',
#   'name': 'Projektor og lerret',
#   'name_eng': 'Projector and screen',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '302',
#   'name': 'Radio',
#   'name_eng': 'Radio',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '55',
#   'name': 'Stereo',
#   'name_eng': 'Stereo',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '62',
#   'name': 'TV',
#   'name_eng': 'Television',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '58',
#   'name': 'Videospillere',
#   'name_eng': 'Video players',
#   'parent': '3906'},
#  {'depth': '2',
#   'id': '64',
#   'name': 'Spill',
#   'name_eng': 'Game',
#   'parent': '3905'},
#  {'depth': '2',
#   'id': '63',
#   'name': 'Spillkonsoller',
#   'name_eng': 'Game consoles',
#   'parent': '3905'},
#  {'depth': '2',
#   'id': '65',
#   'name': 'Tilbehør',
#   'name_eng': 'Accessories',
#   'parent': '3905'},
#  {'depth': '2',
#   'id': '40',
#   'name': 'Andre telefoner',
#   'name_eng': 'Other phones',
#   'parent': '3217'},
#  {'depth': '2',
#   'id': '39',
#   'name': 'Mobiltelefoner',
#   'name_eng': 'Mobile phones',
#   'parent': '3217'},
#  {'depth': '2',
#   'id': '41',
#   'name': 'Telefontilbehør',
#   'name_eng': 'Phone accessories',
#   'parent': '3217'},
#  {'depth': '2',
#   'id': '341',
#   'name': 'Baby',
#   'name_eng': 'Baby',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '342',
#   'name': 'Gutt',
#   'name_eng': 'Boy',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '343',
#   'name': 'Jente',
#   'name_eng': 'Girl',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '380',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3913'},
#  {'depth': '2',
#   'id': '314',
#   'name': 'Bord',
#   'name_eng': 'Table',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '315',
#   'name': 'Oppbevaring',
#   'name_eng': 'Storage',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '312',
#   'name': 'Senger',
#   'name_eng': 'Beds',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '316',
#   'name': 'Stellebord',
#   'name_eng': 'Changing table',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '313',
#   'name': 'Stoler',
#   'name_eng': 'Chairs',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '317',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3916'},
#  {'depth': '2',
#   'id': '381',
#   'name': 'Baby',
#   'name_eng': 'Baby',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '382',
#   'name': 'Gutt',
#   'name_eng': 'Boy',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '383',
#   'name': 'Jente',
#   'name_eng': 'Girl',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '384',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3915'},
#  {'depth': '2',
#   'id': '336',
#   'name': 'Andre leker',
#   'name_eng': 'Other toys',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '330',
#   'name': 'Babyleker',
#   'name_eng': 'Baby toys',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '331',
#   'name': 'Bamser, dukker og figurer',
#   'name_eng': 'Teddy bears, dolls and figurines',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '332',
#   'name': 'Biler og baner',
#   'name_eng': 'Cars and tracks',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '333',
#   'name': 'Lego og byggeklosser',
#   'name_eng': 'Lego and building blocks',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '334',
#   'name': 'Tegne- og formingsutstyr',
#   'name_eng': 'Drawing and shaping equipment',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '335',
#   'name': 'Uteleker',
#   'name_eng': 'Outdoor games',
#   'parent': '3912'},
#  {'depth': '2',
#   'id': '113',
#   'name': 'Flybilletter',
#   'name_eng': 'Airline tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '116',
#   'name': 'Idrettsarrangementer',
#   'name_eng': 'Sports events',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '115',
#   'name': 'Konsertbilletter',
#   'name_eng': 'Concert tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '112',
#   'name': 'Pakkereiser',
#   'name_eng': 'Package tours',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '117',
#   'name': 'Teaterbilletter',
#   'name_eng': 'Theater tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '114',
#   'name': 'Togbilletter',
#   'name_eng': 'Train tickets',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '118',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '7735'},
#  {'depth': '2',
#   'id': '122',
#   'name': 'Andre spill',
#   'name_eng': 'Other games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '120',
#   'name': 'Bordspill',
#   'name_eng': 'Board games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '119',
#   'name': 'Brettspill',
#   'name_eng': 'Board games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '121',
#   'name': 'Hage- og parkspill',
#   'name_eng': 'Garden and park games',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '329',
#   'name': 'Puslespill',
#   'name_eng': 'Puzzle',
#   'parent': '5203'},
#  {'depth': '2',
#   'id': '512',
#   'name': 'Blader og magasiner',
#   'name_eng': 'Magazines and magazines',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '513',
#   'name': 'Faglitteratur',
#   'name_eng': 'Nonfiction',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '520',
#   'name': 'Fakta og dokumentar',
#   'name_eng': 'Facts and documentary',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '94',
#   'name': 'Kokebøker',
#   'name_eng': 'Cookbooks',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '521',
#   'name': 'Oppslagsverk',
#   'name_eng': 'Reference book',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '514',
#   'name': 'Skjønnlitteratur',
#   'name_eng': 'Fiction',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '515',
#   'name': 'Tegneserier',
#   'name_eng': 'cartoons',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '97',
#   'name': 'Øvrige bøker og verk',
#   'name_eng': 'Other books and works',
#   'parent': '5209'},
#  {'depth': '2',
#   'id': '124',
#   'name': 'Garn',
#   'name_eng': 'Yarn',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '130',
#   'name': 'Keramikk',
#   'name_eng': 'Pottery',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '128',
#   'name': 'Maling og maleutstyr',
#   'name_eng': 'Paint and painting equipment',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '131',
#   'name': 'Perler og smykkestener',
#   'name_eng': 'Pearls and gemstones',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '129',
#   'name': 'Scrapbooking',
#   'name_eng': 'Scrapbooking',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '125',
#   'name': 'Stoff',
#   'name_eng': 'Fabric',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '126',
#   'name': 'Sy- og strikkeutstyr',
#   'name_eng': 'Sewing and knitting equipment',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '123',
#   'name': 'Symaskiner',
#   'name_eng': 'Sewing machines',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '132',
#   'name': 'Tresløyd',
#   'name_eng': 'Tree gutted',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '127',
#   'name': 'Vev',
#   'name_eng': 'Loom',
#   'parent': '7734'},
#  {'depth': '2',
#   'id': '102',
#   'name': 'Blu-ray',
#   'name_eng': 'Blu-ray',
#   'parent': '3922'},
#  {'depth': '2', 'id': '98', 'name': 'CD', 'name_eng': 'CD', 'parent': '3922'},
#  {'depth': '2',
#   'id': '100',
#   'name': 'DVD',
#   'name_eng': 'DVD',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '402',
#   'name': 'Kassetter',
#   'name_eng': 'Cassettes',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '99',
#   'name': 'LP/EP',
#   'name_eng': 'LP/EP',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '101',
#   'name': 'VHS',
#   'name_eng': 'VHS',
#   'parent': '3922'},
#  {'depth': '2',
#   'id': '106',
#   'name': 'Andre strengeinstrumenter',
#   'name_eng': 'Other stringed instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '296',
#   'name': 'Bassgitarer',
#   'name_eng': 'Bass guitars',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '295',
#   'name': 'Gitarer',
#   'name_eng': 'Guitars',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '110',
#   'name': 'Keyboard/synth',
#   'name_eng': 'Keyboard/synth',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '108',
#   'name': 'Lydutstyr',
#   'name_eng': 'Audio equipment',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '104',
#   'name': 'Messinginstrumenter',
#   'name_eng': 'Brass instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '337',
#   'name': 'Orgler',
#   'name_eng': 'Organs',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '109',
#   'name': 'Piano/flygel',
#   'name_eng': 'Piano/grand piano',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '107',
#   'name': 'Slagverk',
#   'name_eng': 'Percussion',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '105',
#   'name': 'Strykeinstrumenter',
#   'name_eng': 'String instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '103',
#   'name': 'Treblåsere',
#   'name_eng': 'Woodwinds',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '328',
#   'name': 'Trekkspill',
#   'name_eng': 'Accordion',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '111',
#   'name': 'Øvrige instrumenter',
#   'name_eng': 'Other instruments',
#   'parent': '92'},
#  {'depth': '2',
#   'id': '133',
#   'name': 'Bil',
#   'name_eng': 'Car',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '134',
#   'name': 'Båt',
#   'name_eng': 'Boat',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '401',
#   'name': 'Drone',
#   'name_eng': 'Drone',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '135',
#   'name': 'Fly',
#   'name_eng': 'Fly',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '136',
#   'name': 'Helikopter',
#   'name_eng': 'Helicopter',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '327',
#   'name': 'Modelljernbaner',
#   'name_eng': 'Model railways',
#   'parent': '7733'},
#  {'depth': '2',
#   'id': '141',
#   'name': 'Andre samlinger',
#   'name_eng': 'Other collections',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '137',
#   'name': 'Frimerker',
#   'name_eng': 'Stamps',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '399',
#   'name': 'Leker',
#   'name_eng': 'Toys',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '397',
#   'name': 'Militæreffekter',
#   'name_eng': 'Military effects',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '138',
#   'name': 'Mynter og sedler',
#   'name_eng': 'Coins and banknotes',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '139',
#   'name': 'Pins',
#   'name_eng': 'Pentecost',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '140',
#   'name': 'Postkort',
#   'name_eng': 'Postcard',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '400',
#   'name': 'Samlefigurer',
#   'name_eng': 'Collectible figures',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '396',
#   'name': 'Samlekort',
#   'name_eng': 'Trading cards',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '398',
#   'name': 'Skilt og plakater',
#   'name_eng': 'Signs and posters',
#   'parent': '285'},
#  {'depth': '2',
#   'id': '157',
#   'name': 'Badekar',
#   'name_eng': 'Bathtub',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '164',
#   'name': 'Baderomsmøbler',
#   'name_eng': 'Bathroom furniture',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '158',
#   'name': 'Badstuer',
#   'name_eng': 'Saunas',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '156',
#   'name': 'Blandebatterier',
#   'name_eng': 'Mixer taps',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '160',
#   'name': 'Dusjkabinett og -vegger',
#   'name_eng': 'Shower enclosure and walls',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '162',
#   'name': 'Servanter',
#   'name_eng': 'Sinks',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '159',
#   'name': 'Steamdusjer',
#   'name_eng': 'Steam showers',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '163',
#   'name': 'Tilbehør',
#   'name_eng': 'Accessories',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '161',
#   'name': 'Toaletter',
#   'name_eng': 'Toilets',
#   'parent': '7749'},
#  {'depth': '2',
#   'id': '165',
#   'name': 'Andre byggevarer',
#   'name_eng': 'Other building materials',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '166',
#   'name': 'Byggesett',
#   'name_eng': 'Construction kit',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '169',
#   'name': 'Dører',
#   'name_eng': 'Doors',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '167',
#   'name': 'Gulv',
#   'name_eng': 'Floor',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '301',
#   'name': 'Tapet og maling',
#   'name_eng': 'Wallpaper and paint',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '346',
#   'name': 'Trapper',
#   'name_eng': 'Stairs',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '168',
#   'name': 'Vinduer',
#   'name_eng': 'Windows',
#   'parent': '3899'},
#  {'depth': '2',
#   'id': '145',
#   'name': 'Annet hageutstyr',
#   'name_eng': 'Other garden equipment',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '339',
#   'name': 'Beplantning og tilbehør',
#   'name_eng': 'Planting and accessories',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '149',
#   'name': 'Gressklippere',
#   'name_eng': 'Lawnmowers',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '147',
#   'name': 'Grill',
#   'name_eng': 'Barbecue',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '142',
#   'name': 'Hagemøbler',
#   'name_eng': 'Garden furniture',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '143',
#   'name': 'Hageredskap',
#   'name_eng': 'Garden tools',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '146',
#   'name': 'Markiser og parasoller',
#   'name_eng': 'Awnings and parasols',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '144',
#   'name': 'Partytelt',
#   'name_eng': 'Party tent',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '148',
#   'name': 'Snørydding',
#   'name_eng': 'Snow removal',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '150',
#   'name': 'Svømmebasseng og spabad',
#   'name_eng': 'Swimming pool and hot tub',
#   'parent': '3901'},
#  {'depth': '2',
#   'id': '297',
#   'name': 'Aircondition og vifter',
#   'name_eng': 'Air conditioning and fans',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '155',
#   'name': 'Elektriske ovner',
#   'name_eng': 'Electric ovens',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '151',
#   'name': 'Ovner',
#   'name_eng': 'Ovens',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '152',
#   'name': 'Peis',
#   'name_eng': 'Fireplace',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '154',
#   'name': 'Varmepumper',
#   'name_eng': 'Heat pumps',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '153',
#   'name': 'Ved og brensel',
#   'name_eng': 'Firewood and fuel',
#   'parent': '5218'},
#  {'depth': '2',
#   'id': '200',
#   'name': 'Briller',
#   'name_eng': 'Glasses',
#   'parent': '8344'},
#  {'depth': '2',
#   'id': '201',
#   'name': 'Linser',
#   'name_eng': 'Lentils',
#   'parent': '8344'},
#  {'depth': '2',
#   'id': '199',
#   'name': 'Solbriller',
#   'name_eng': 'Sunglasses',
#   'parent': '8344'},
#  {'depth': '2',
#   'id': '171',
#   'name': 'Brudekjoler',
#   'name_eng': 'Wedding dresses',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '174',
#   'name': 'Bukser',
#   'name_eng': 'Pants',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '170',
#   'name': 'Bunader',
#   'name_eng': 'Bunader',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '177',
#   'name': 'Gensere',
#   'name_eng': 'Sweaters',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '178',
#   'name': 'Jakker',
#   'name_eng': 'Jackets',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '172',
#   'name': 'Kjoler',
#   'name_eng': 'Dresses',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '310',
#   'name': 'Luer, skjerf og votter',
#   'name_eng': 'Hats, scarves and mittens',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '180',
#   'name': 'Skjorter',
#   'name_eng': 'Shirts',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '175',
#   'name': 'Skjørt',
#   'name_eng': 'Skirt',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '179',
#   'name': 'T-skjorter',
#   'name_eng': 'T shirts',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '176',
#   'name': 'Topper',
#   'name_eng': 'Tops',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '181',
#   'name': 'Undertøy',
#   'name_eng': 'Underwear',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '173',
#   'name': 'Ytterklær',
#   'name_eng': 'Outerwear',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '182',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3941'},
#  {'depth': '2',
#   'id': '184',
#   'name': 'Bukser',
#   'name_eng': 'Pants',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '188',
#   'name': 'Bunader',
#   'name_eng': 'Bunader',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '189',
#   'name': 'Dresser',
#   'name_eng': 'Suits',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '186',
#   'name': 'Gensere',
#   'name_eng': 'Sweaters',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '311',
#   'name': 'Luer, skjerf og votter',
#   'name_eng': 'Hats, scarves and mittens',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '185',
#   'name': 'Skjorter',
#   'name_eng': 'Shirts',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '190',
#   'name': 'Smokinger',
#   'name_eng': 'Tuxedos',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '187',
#   'name': 'T-skjorter',
#   'name_eng': 'T shirts',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '191',
#   'name': 'Undertøy',
#   'name_eng': 'Underwear',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '183',
#   'name': 'Ytterklær',
#   'name_eng': 'Outerwear',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '192',
#   'name': 'Annet',
#   'name_eng': 'Other',
#   'parent': '3950'},
#  {'depth': '2',
#   'id': '194',
#   'name': 'Damesko',
#   'name_eng': "Women's shoes",
#   'parent': '3949'},
#  {'depth': '2',
#   'id': '193',
#   'name': 'Herresko',
#   'name_eng': "Men's shoes",
#   'parent': '3949'},
#  {'depth': '2',
#   'id': '306',
#   'name': 'Andre smykker',
#   'name_eng': 'Other jewelry',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '198',
#   'name': 'Armbånd',
#   'name_eng': 'Bracelet',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '195',
#   'name': 'Halskjeder',
#   'name_eng': 'Necklaces',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '196',
#   'name': 'Ringer',
#   'name_eng': 'Calls',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '307',
#   'name': 'Smykkeskrin og oppbevaring',
#   'name_eng': 'Jewelery box and storage',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '197',
#   'name': 'Ørepynt',
#   'name_eng': 'Earrings',
#   'parent': '7748'},
#  {'depth': '2',
#   'id': '230',
#   'name': 'Andre lamper',
#   'name_eng': 'Other lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '229',
#   'name': 'Bordlamper',
#   'name_eng': 'Table lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '228',
#   'name': 'Stålamper',
#   'name_eng': 'Steel lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '226',
#   'name': 'Taklamper',
#   'name_eng': 'Ceiling lights',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '227',
#   'name': 'Vegglamper',
#   'name_eng': 'Wall lamps',
#   'parent': '5181'},
#  {'depth': '2',
#   'id': '217',
#   'name': 'Andre bord og stoler',
#   'name_eng': 'Other tables and chairs',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '213',
#   'name': 'Kjøkkenbord',
#   'name_eng': 'Kitchen table',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '215',
#   'name': 'Kontorstoler',
#   'name_eng': 'Office chairs',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '212',
#   'name': 'Salongbord',
#   'name_eng': 'Coffee table',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '214',
#   'name': 'Skrivebord',
#   'name_eng': 'Desk',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '211',
#   'name': 'Spisestuer',
#   'name_eng': 'Dining rooms',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '216',
#   'name': 'Stoler og krakker',
#   'name_eng': 'Chairs and stools',
#   'parent': '5196'},
#  {'depth': '2',
#   'id': '241',
#   'name': 'Andre pyntgjenstander',
#   'name_eng': 'Other decorative items',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '237',
#   'name': 'Bilder og rammer',
#   'name_eng': 'Pictures and frames',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '239',
#   'name': 'Fat',
#   'name_eng': 'Barrel',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '240',
#   'name': 'Lysestaker',
#   'name_eng': 'Candlesticks',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '299',
#   'name': 'Speil',
#   'name_eng': 'Mirror',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '238',
#   'name': 'Vaser',
#   'name_eng': 'Vases',
#   'parent': '5222'},
#  {'depth': '2',
#   'id': '218',
#   'name': 'Garderober',
#   'name_eng': 'Wardrobes',
#   'parent': '5198'},
#  {'depth': '2',
#   'id': '222',
#   'name': 'Seksjoner',
#   'name_eng': 'Sections',
#   'parent': '5198'},
#  {'depth': '2',
#   'id': '225',
#   'name': 'Skap',
#   'name_eng': 'Cabinet',
#   'parent': '5198'},
#  {'depth': '2',
#   'id': '219',
#   'name': 'Hyller',
#   'name_eng': 'Shelves',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '221',
#   'name': 'Kommoder',
#   'name_eng': 'Chest of drawers',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '223',
#   'name': 'Nattbord',
#   'name_eng': 'Bedside table',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '220',
#   'name': 'Skjenk',
#   'name_eng': 'Sideboard',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '224',
#   'name': 'TV-møbler',
#   'name_eng': 'TV furniture',
#   'parent': '8345'},
#  {'depth': '2',
#   'id': '203',
#   'name': 'Madrasser',
#   'name_eng': 'Mattresses',
#   'parent': '5197'},
#  {'depth': '2',
#   'id': '293',
#   'name': 'Rammemadrasser',
#   'name_eng': 'Frame mattresses',
#   'parent': '5197'},
#  {'depth': '2',
#   'id': '202',
#   'name': 'Senger',
#   'name_eng': 'Beds',
#   'parent': '5197'},
#  {'depth': '2',
#   'id': '204',
#   'name': '2-seter',
#   'name_eng': '2-seater',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '205',
#   'name': '3-seter',
#   'name_eng': '3-seater',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '207',
#   'name': 'Hjørnesofaer',
#   'name_eng': 'Corner sofas',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '210',
#   'name': 'Lenestoler',
#   'name_eng': 'Armchairs',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '209',
#   'name': 'Puffer',
#   'name_eng': 'Poufs',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '208',
#   'name': 'Sofagrupper',
#   'name_eng': 'Sofa groups',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '206',
#   'name': 'Sovesofaer',
#   'name_eng': 'Sofa beds',
#   'parent': '7756'},
#  {'depth': '2',
#   'id': '235',
#   'name': 'Andre tekstiler',
#   'name_eng': 'Other textiles',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '233',
#   'name': 'Duker',
#   'name_eng': 'Tablecloths',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '234',
#   'name': 'Gardiner',
#   'name_eng': 'Curtains',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '232',
#   'name': 'Puter',
#   'name_eng': 'Pillows',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '231',
#   'name': 'Tepper',
#   'name_eng': 'Carpets',
#   'parent': '5180'},
#  {'depth': '2',
#   'id': '364',
#   'name': 'Annet butikkutstyr',
#   'name_eng': 'Other shop equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '358',
#   'name': 'Betalingsutstyr',
#   'name_eng': 'Payment equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '362',
#   'name': 'Butikkbelysning',
#   'name_eng': 'Shop lighting',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '359',
#   'name': 'Butikkinnredning',
#   'name_eng': 'Shop furnishings',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '361',
#   'name': 'Lagerutstyr',
#   'name_eng': 'Storage equipment',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '360',
#   'name': 'Sikkerhet og overvåkning',
#   'name_eng': 'Security and monitoring',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '363',
#   'name': 'Vareparti og konkursbo',
#   'name_eng': 'Goods lot and bankruptcy estate',
#   'parent': '3108'},
#  {'depth': '2',
#   'id': '368',
#   'name': 'Annet anleggsutstyr',
#   'name_eng': 'Other construction equipment',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '366',
#   'name': 'Brakker',
#   'name_eng': 'Barracks',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '365',
#   'name': 'Containere',
#   'name_eng': 'Containers',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '367',
#   'name': 'Mannskapsvogner',
#   'name_eng': 'Crew cars',
#   'parent': '3111'},
#  {'depth': '2',
#   'id': '357',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '347',
#   'name': 'Førstehjelpsutstyr',
#   'name_eng': 'First aid equipment',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '348',
#   'name': 'Hjelpemidler',
#   'name_eng': 'Aids',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '349',
#   'name': 'Hud- og kroppspleie',
#   'name_eng': 'Skin and body care',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '350',
#   'name': 'Utstyr og inventar',
#   'name_eng': 'Equipment and inventory',
#   'parent': '8343'},
#  {'depth': '2',
#   'id': '294',
#   'name': 'Innredning',
#   'name_eng': 'Furnishing',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '243',
#   'name': 'Kopimaskiner',
#   'name_eng': 'Copy machines',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '244',
#   'name': 'Printere',
#   'name_eng': 'Printers',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '242',
#   'name': 'Rekvisita',
#   'name_eng': 'Props',
#   'parent': '3105'},
#  {'depth': '2',
#   'id': '403',
#   'name': 'Havplast',
#   'name_eng': 'Marine plastic',
#   'parent': '3115'},
#  {'depth': '2',
#   'id': '356',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '355',
#   'name': 'Innredning',
#   'name_eng': 'Furnishing',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '351',
#   'name': 'Kjøkkenutstyr',
#   'name_eng': 'Kitchen equipment',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '352',
#   'name': 'Kjøl og frys',
#   'name_eng': 'Refrigerate and freeze',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '353',
#   'name': 'Koke- og stekeprodukter',
#   'name_eng': 'Cooking and baking products',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '354',
#   'name': 'Oppvask',
#   'name_eng': 'Dishwashing',
#   'parent': '3103'},
#  {'depth': '2',
#   'id': '379',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '372',
#   'name': 'Byggtørkere',
#   'name_eng': 'Building dryers',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '373',
#   'name': 'Kompressor',
#   'name_eng': 'Compressor',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '378',
#   'name': 'Lagerhall',
#   'name_eng': 'Warehouse',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '371',
#   'name': 'Lys',
#   'name_eng': 'Light',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '377',
#   'name': 'Maskiner og utstyr',
#   'name_eng': 'Machinery and equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '376',
#   'name': 'Maskinutleie',
#   'name_eng': 'Machine rental',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '374',
#   'name': 'Stillas og reoler',
#   'name_eng': 'Scaffolding and shelving',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '375',
#   'name': 'Treforedling',
#   'name_eng': 'Wood processing',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '370',
#   'name': 'Verkstedsutstyr',
#   'name_eng': 'Workshop equipment',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '369',
#   'name': 'Verktøy',
#   'name_eng': 'Tool',
#   'parent': '3102'},
#  {'depth': '2',
#   'id': '251',
#   'name': 'Annen ballsport',
#   'name_eng': 'Other ball sports',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '250',
#   'name': 'Bandy',
#   'name_eng': 'Bandy',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '247',
#   'name': 'Basketball',
#   'name_eng': 'Basketball',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '245',
#   'name': 'Fotball',
#   'name_eng': 'Soccer',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '246',
#   'name': 'Håndball',
#   'name_eng': 'handball',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '249',
#   'name': 'Tennis',
#   'name_eng': 'Tennis',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '248',
#   'name': 'Volleyball',
#   'name_eng': 'Volleyball',
#   'parent': '3961'},
#  {'depth': '2',
#   'id': '266',
#   'name': 'Fallskjermhopping',
#   'name_eng': 'Skydiving',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '264',
#   'name': 'Kiting',
#   'name_eng': 'Kiting',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '265',
#   'name': 'Klatring',
#   'name_eng': 'Climbing',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '267',
#   'name': 'Skate- og longboard',
#   'name_eng': 'Skate and longboard',
#   'parent': '3938'},
#  {'depth': '2',
#   'id': '275',
#   'name': 'Annet fiskeutstyr',
#   'name_eng': 'Other fishing equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '270',
#   'name': 'Annet jaktutstyr',
#   'name_eng': 'Other hunting equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '280',
#   'name': 'Annet turutstyr',
#   'name_eng': 'Other hiking equipment',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '274',
#   'name': 'Fiskeklær',
#   'name_eng': 'Fishing clothes',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '271',
#   'name': 'Fiskestenger',
#   'name_eng': 'Fishing rods',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '269',
#   'name': 'Jaktklær',
#   'name_eng': 'Hunting clothes',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '279',
#   'name': 'Kano',
#   'name_eng': 'Canoe',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '300',
#   'name': 'Kikkerter og optikk',
#   'name_eng': 'Binoculars and optics',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '278',
#   'name': 'Ryggsekker',
#   'name_eng': 'Backpacks',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '273',
#   'name': 'Sneller, fluer og kroker',
#   'name_eng': 'Reels, flies and hooks',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '276',
#   'name': 'Soveposer',
#   'name_eng': 'Sleeping bags',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '272',
#   'name': 'Teiner og garn',
#   'name_eng': 'Twine and yarn',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '277',
#   'name': 'Telt',
#   'name_eng': 'Tent',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '268',
#   'name': 'Våpen',
#   'name_eng': 'Arms',
#   'parent': '3964'},
#  {'depth': '2',
#   'id': '253',
#   'name': 'Alpint',
#   'name_eng': 'Alpine',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '256',
#   'name': 'Annet skiutstyr',
#   'name_eng': 'Other ski equipment',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '255',
#   'name': 'Langrenn',
#   'name_eng': 'Cross-country skiing',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '252',
#   'name': 'Snowboard',
#   'name_eng': 'Snowboarding',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '254',
#   'name': 'Telemark',
#   'name_eng': 'Telemark',
#   'parent': '3962'},
#  {'depth': '2',
#   'id': '405',
#   'name': 'Skøyter til barn',
#   'name_eng': 'Skates for children',
#   'parent': '8346'},
#  {'depth': '2',
#   'id': '404',
#   'name': 'Skøyter til voksne',
#   'name_eng': 'Skates for adults',
#   'parent': '8346'},
#  {'depth': '2',
#   'id': '406',
#   'name': 'Skøyteutstyr',
#   'name_eng': 'Skating equipment',
#   'parent': '8346'},
#  {'depth': '2',
#   'id': '3983',
#   'name': 'Barneklær',
#   'name_eng': "Children's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3981',
#   'name': 'Dameklær',
#   'name_eng': "Women's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3980',
#   'name': 'Herreklær',
#   'name_eng': "Men's clothing",
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3984',
#   'name': 'Sko',
#   'name_eng': 'Shoe',
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '3982',
#   'name': 'Unisex',
#   'name_eng': 'Unisex',
#   'parent': '3940'},
#  {'depth': '2',
#   'id': '284',
#   'name': 'Luftvåpen',
#   'name_eng': 'Air weapons',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '281',
#   'name': 'Paintball',
#   'name_eng': 'Paintball',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '282',
#   'name': 'Pistol',
#   'name_eng': 'Pistol',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '283',
#   'name': 'Softgun',
#   'name_eng': 'Softgun',
#   'parent': '3965'},
#  {'depth': '2',
#   'id': '257',
#   'name': 'Sykler',
#   'name_eng': 'Bicycles',
#   'parent': '3963'},
#  {'depth': '2',
#   'id': '258',
#   'name': 'Utstyr',
#   'name_eng': 'Equipment',
#   'parent': '3963'},
#  {'depth': '2',
#   'id': '291',
#   'name': 'Ellipsemaskiner',
#   'name_eng': 'Elliptical machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '287',
#   'name': 'Romaskiner',
#   'name_eng': 'Rowing machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '290',
#   'name': 'Stepmaskiner',
#   'name_eng': 'Step machines',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '288',
#   'name': 'Styrkeapparater',
#   'name_eng': 'Strength equipment',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '516',
#   'name': 'Tredemøller',
#   'name_eng': 'Treadmills',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '286',
#   'name': 'Treningssykler',
#   'name_eng': 'Exercise bikes',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '289',
#   'name': 'Treningsutstyr',
#   'name_eng': 'Training equipment',
#   'parent': '5166'},
#  {'depth': '2',
#   'id': '263',
#   'name': 'Annet utstyr',
#   'name_eng': 'Other equipment',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '259',
#   'name': 'Dykking',
#   'name_eng': 'Diving',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '260',
#   'name': 'Padling',
#   'name_eng': 'Paddling',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '261',
#   'name': 'Seiling',
#   'name_eng': 'Sailing',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '262',
#   'name': 'Surfing',
#   'name_eng': 'Surfing',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '338',
#   'name': 'Windsurf',
#   'name_eng': 'Windsurfing',
#   'parent': '7738'},
#  {'depth': '2',
#   'id': '9',
#   'name': 'Annet biltilbehør',
#   'name_eng': 'Other car accessories',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '2',
#   'name': 'Bildeler',
#   'name_eng': 'Car parts',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '3',
#   'name': 'Bilseter',
#   'name_eng': 'Car seats',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '5',
#   'name': 'Bilstereo',
#   'name_eng': 'Car stereo',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '6',
#   'name': 'Dekk og felger',
#   'name_eng': 'Tires and rims',
#   'parent': '82'},
#  {'depth': '2', 'id': '344', 'name': 'GPS', 'name_eng': 'GPS', 'parent': '82'},
#  {'depth': '2',
#   'id': '8',
#   'name': 'Styling',
#   'name_eng': 'Styling',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '4',
#   'name': 'Takstativ og boks',
#   'name_eng': 'Roof rack and box',
#   'parent': '82'},
#  {'depth': '2',
#   'id': '325',
#   'name': 'Annet båtutstyr',
#   'name_eng': 'Other boat equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '318',
#   'name': 'Elektronikk',
#   'name_eng': 'Electronics',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '324',
#   'name': 'Fortøyningsutstyr',
#   'name_eng': 'Mooring equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '320',
#   'name': 'Interiør og eksteriør',
#   'name_eng': 'Interior and exterior',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '340',
#   'name': 'Motordeler',
#   'name_eng': 'Engine parts',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '345',
#   'name': 'Navigasjon',
#   'name_eng': 'Navigation',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '323',
#   'name': 'Seilbåtutstyr',
#   'name_eng': 'Sailboat equipment',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '322',
#   'name': 'Sikkerhet',
#   'name_eng': 'Safety',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '319',
#   'name': 'Strøm og VVS',
#   'name_eng': 'Electricity and plumbing',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '321',
#   'name': 'Styring og vinsj',
#   'name_eng': 'Steering and winch',
#   'parent': '30'},
#  {'depth': '2',
#   'id': '10',
#   'name': 'MC-deler',
#   'name_eng': 'MC parts',
#   'parent': '20'},
#  {'depth': '2',
#   'id': '12',
#   'name': 'MC-klær',
#   'name_eng': 'MC clothing',
#   'parent': '20'},
#  {'depth': '2',
#   'id': '11',
#   'name': 'MC-tilbehør',
#   'name_eng': 'MC accessories',
#   'parent': '20'},
#  {'depth': '2',
#   'id': '16',
#   'name': 'ATV- og MC-hengere',
#   'name_eng': 'ATV and MC trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '17',
#   'name': 'Biltransporthengere',
#   'name_eng': 'Car transport trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '14',
#   'name': 'Båt- og opplagshengere',
#   'name_eng': 'Boat and storage trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '19',
#   'name': 'Hestehengere',
#   'name_eng': 'Horse trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '18',
#   'name': 'Maskinhengere',
#   'name_eng': 'Machine trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '15',
#   'name': 'Skaphengere',
#   'name_eng': 'Closet hangers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '517',
#   'name': 'Termohengere',
#   'name_eng': 'Thermal hangers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '308',
#   'name': 'Tilhengertilbehør',
#   'name_eng': 'Trailer accessories',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '309',
#   'name': 'Tipphengere',
#   'name_eng': 'Tipper trailers',
#   'parent': '80'},
#  {'depth': '2',
#   'id': '13',
#   'name': 'Varehengere',
#   'name_eng': 'Goods trailers',
#   'parent': '80'}]

# %%
def category_candidates(category: str):
    category_eng = translate_to_eng(category)
    return [
        (simularity(category_eng, p["name_eng"]), p)
        for p in product_categories
        if simularity(category_eng, p["name_eng"]) > 0.5
    ]


pprint(category_candidates("oerepropper"))
print()
# pprint(category_candidates("Hodetelefoner"))
print()
pprint(category_candidates("true-wireless-hodetelefoner"))
print()
pprint(category_candidates("headsets"))
# Out:
# [(0.58270264,
#   {'depth': '2',
#    'id': '51',
#    'name': 'Hodetelefoner',
#    'name_eng': 'Headphones',
#    'parent': '3906'})]
#
#
# [(0.59127533,
#   {'depth': '2',
#    'id': '51',
#    'name': 'Hodetelefoner',
#    'name_eng': 'Headphones',
#    'parent': '3906'})]
#
# [(0.73707205,
#   {'depth': '2',
#    'id': '51',
#    'name': 'Hodetelefoner',
#    'name_eng': 'Headphones',
#    'parent': '3906'}),
#  (0.50662947,
#   {'depth': '2',
#    'id': '53',
#    'name': 'Høyttalere',
#    'name_eng': 'Speakers',
#    'parent': '3906'}),
#  (0.51122034,
#   {'depth': '2',
#    'id': '39',
#    'name': 'Mobiltelefoner',
#    'name_eng': 'Mobile phones',
#    'parent': '3217'}),
#  (0.50918305,
#   {'depth': '2',
#    'id': '108',
#    'name': 'Lydutstyr',
#    'name_eng': 'Audio equipment',
#    'parent': '92'})]

# %%
test_categories = ["tv-lyd-bilde", "hodetelefoner-tilbehoer", "oerepropper"]
translated_categories = [translate_to_eng(c) for c in test_categories]
print(translated_categories)
# Out:
# ['TV sound image', 'headphone accessories', 'earplugs']

# %%
def get_finn_category_parent(category: dict) -> dict:
    if category["parent"] is None: return None
    return next(c for c in finn_categories if c["id"] == category["parent"])

def get_finn_category_parents(category: dict) -> list[dict]:
    parent = get_finn_category_parent(category)
    if not parent:
        return []
    
    return [parent, *get_finn_category_parents(parent) ]


get_finn_category_parents(
    {
        "name": "Hodetelefoner",
        "name_eng": "Headphones",
        "id": "51",
        "depth": "2",
        "parent": "3906",
    }
)
# Out:
# [{'name': 'Lyd og bilde',
#   'name_eng': 'Sound and image',
#   'id': '3906',
#   'depth': '1',
#   'parent': '93'},
#  {'name': 'Elektronikk og hvitevarer',
#   'name_eng': 'Electronics and appliances',
#   'id': '93',
#   'depth': '0',
#   'parent': None}]

# %%
import itertools


def parse_categories(categories: list[str]):
    l = 0
    found_categories = []
    while l < len(categories) and len(found_categories) < 10:
        l += 1
        scores = []
        for finn_category in [*product_categories, *sub_categories]:
            name_eng = finn_category["name_eng"]
            score = simularity(name_eng, categories[-l])
            scores.append((score, finn_category))

        scores.sort(key=lambda s: s[0], reverse=True)

        found_categories.extend([cat for s, cat in scores[:10] if s > 0.3])

    scores = []

    for finn_category in found_categories:
        parents = get_finn_category_parents(finn_category)
        finn_category_names = [finn_category, *parents]
        finn_category_names = [c["name_eng"] for c in finn_category_names]

        product = itertools.product(finn_category_names, categories)
        score = max(simularity(a, b) for a, b in product)
        scores.append((score, finn_category))

    scores.sort(key=lambda s: s[0], reverse=True)

    _, finn_category = scores[0]

    parents = get_finn_category_parents(finn_category)
    category_and_parents = [finn_category, *parents][::-1]
    finn_category_ids = [c["id"] for c in category_and_parents]
    names = [c["name"] for c in category_and_parents]

    n = len(category_and_parents)

    prefix = ["category", "sub_category", "product_category"][n-1]
    code = f"{prefix}={n-1}.{'.'.join(finn_category_ids)}"

    return code, names


print(parse_categories(translated_categories))
print(parse_categories(["tv and video", "CANNON cameras"]))
print(parse_categories(["Activities and art", "Antique furniture"]))
print(parse_categories(["hardware", "phones and gps", "smartphone accessories", "headsets"]))
# Out:
# ('product_category=2.93.3906.51', ['Elektronikk og hvitevarer', 'Lyd og bilde', 'Hodetelefoner'])
# ('product_category=2.93.3904.504', ['Elektronikk og hvitevarer', 'Foto og video', 'Videokameraer'])
# ('sub_category=1.76.5178', ['Antikviteter og kunst', 'Antikke møbler'])
# ('product_category=2.93.3906.51', ['Elektronikk og hvitevarer', 'Lyd og bilde', 'Hodetelefoner'])

# %%
depth_scores = {
    0: 0.5,
    1: 1.0,
    2: 2.0,
}

def find_score(category_list: list[str], finn_category: dict):
    i_multipliers = {
        0: 10,
        1: 3,
        2: 1,
    }    

    j_multipliers = {
        0: 5,
        1: 2,
        2: 2,
    }

    parents = get_finn_category_parents(finn_category)
    finn_category_list = [*parents[::-1], finn_category]

    score = 0
    for i, category_list_name in enumerate(category_list[::-1]):
        for j, finn_category_list_name in enumerate(finn_category_list[::-1]):
            current = simularity(category_list_name, finn_category_list_name["name_eng"])
            current *= i_multipliers.get(i, 1)
            current *= j_multipliers.get(j, 1)
            score += current
    
    return score

def find_simular_category(category_list: list[str]) -> dict:
    best_score = -1
    current_result = None

    for category in finn_categories:
        depth = int(category["depth"])
        score = find_score(category_list, category) * depth_scores[depth]

        if score > best_score:
            best_score = score
            current_result = category
    
    return current_result, best_score

print(find_simular_category(["hardware", "phones and gps", "smartphone accessories", "headsets"]))
print(find_simular_category(["tv and video", "CANNON cameras"]))
print(find_simular_category(["Activities and art", "Antique furniture"]))
print(find_simular_category(translated_categories))
# Out:
# ({'name': 'Hodetelefoner', 'name_eng': 'Headphones', 'id': '51', 'depth': '2', 'parent': '3906'}, 124.9007078409195)
# ({'name': 'Videokameraer', 'name_eng': 'Video cameras', 'id': '504', 'depth': '2', 'parent': '3904'}, 119.40600973367691)
# ({'name': 'TV-møbler', 'name_eng': 'TV furniture', 'id': '224', 'depth': '2', 'parent': '8345'}, 98.43382042646408)
# ({'name': 'Hodetelefoner', 'name_eng': 'Headphones', 'id': '51', 'depth': '2', 'parent': '3906'}, 107.04406434297562)

# %%
# TODO: find most fitting finn category name for each name first

def most_fitting_finn_category(name: str, predicted_depth: int) -> dict:
    best_score = 0
    best_finn_category = None
    for finn_category in finn_categories:
        parents = get_finn_category_parents(finn_category)
        actual_depth = len(parents)

        finn_name = finn_category["name_eng"]
        score = simularity(name, finn_name) / (1.4 ** abs(actual_depth - predicted_depth))

        if score > best_score:
            best_score = score
            best_finn_category = finn_category

    return best_finn_category

def category_list_to_finn_category(category_list: list[str]) -> dict:
    def candidates():
        for i, name in enumerate(category_list):
            predicted_depth = i * 2 / (len(category_list) - 1)
            yield most_fitting_finn_category(name, predicted_depth)

    best_score = 0
    best_candidate = None

    for i, candidate in enumerate(candidates()):
        predicted_depth = i * 2 / (len(category_list) - 1)
        actual_depth = int(candidate["depth"])

        score = simularity(candidate["name_eng"], category_list[i])
        score *= 2 * (actual_depth + 1)
        score /= 1.2 ** abs(predicted_depth - actual_depth)

        if score > best_score:
            best_score = score
            best_candidate = candidate

    return best_candidate

def format_finn_category(finn_category):
    parents = get_finn_category_parents(finn_category)
    full_category = [*parents[::-1], finn_category]
    full_category_name = "/".join(c["name_eng"] for c in full_category)
    return full_category_name

category_lists = [
    ["hardware", "phones and gps", "smartphone accessories", "headsets"],
    ["tv and video", "CANNON cameras"],
    ["Activities and art", "Antique furniture"],
    translated_categories,
]

for category_list in category_lists:
    finn_category = category_list_to_finn_category(category_list)
    formatted = format_finn_category(finn_category)
    print(f'"{"/".join(category_list)}" --> "{formatted}"')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 52
#      45     full_category_name = "/".join(c["name_eng"] for c in full_category)
#      46     return full_category_name
#      48 category_lists = [
#      49     ["hardware", "phones and gps", "smartphone accessories", "headsets"],
#      50     ["tv and video", "CANNON cameras"],
#      51     ["Activities and art", "Antique furniture"],
# ---> 52     translated_categories,
#      53 ]
#      55 for category_list in category_lists:
#      56     finn_category = category_list_to_finn_category(category_list)
#
# NameError: name 'translated_categories' is not defined
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# TODO: write tests to determine the effectiveness of this function
